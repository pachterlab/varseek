# %% [markdown]
# # Imports

# %%
import os
import subprocess
import varseek as vk

# %% [markdown]
# # Hyperparameters and Paths

# %%
verbose=True
w=54  # window size for varseek build (should be at least 1 less than kallisto k)
k=59
k_standard = 31
threads = 8
remove_Ns = True
strandedness = False  # strandedness for gget mutate and the building of the kb index (True = strandedness matters i.e., treat f and rc as 2 different sequences; False = strandedness does not matter i.e., treat f and rc as the same 

# vk build
cosmic_version = 100  # COSMIC version for gget cosmic
insertion_size_limit = None
# os.environ['COSMIC_EMAIL'] = 'your_email'  # to avoid being prompted for email in varseek build
# os.environ['COSMIC_PASSWORD'] = 'your_password'  # to avoid being prompted for password in varseek build

# vk info
columns_to_include="all"
dlist_reference_source = "t2t"  # ensembl_grchNUMBER_releaseNUMBER or t2t - eg ensembl_grch37_release93
near_splice_junction_threshold=10
save_exploded_df=True

# vk filter
fasta_filters = [
    "dlist_substring-equal=none",  # filter out mutations which are a substring of the reference genome
    "pseudoaligned_to_human_reference_despite_not_truly_aligning-isnottrue",  # filter out mutations which pseudoaligned to human genome despite not truly aligning
    "dlist-equal=none",  #*** erase eventually when I want to d-list  # filter out mutations which are capable of being d-listed (given that I filter out the substrings above)
    "number_of_kmers_with_overlap_to_other_mcrs_items_in_mcrs_reference-max=999999",  # filter out mutations which overlap with other MCRSs in the reference
    "number_of_mcrs_items_with_overlapping_kmers_in_mcrs_reference-max=999999",  # filter out mutations which overlap with other MCRSs in the reference
    "longest_homopolymer_length-max=999999",  # filters out MCRSs with repeating single nucleotide - eg 6
    "triplet_complexity-min=0"  # filters out MCRSs with repeating triplets - eg 0.2
]

# kb ref
dlist = False







# Paths
out_dir_base = "/home/jrich/data/varseek_data_fresh"
run_name = "vk_build_pipeline_t2t_nov16"

# vk build
mutations = "/home/jrich/data/varseek_data_fresh/reference/cosmic/CancerMutationCensus_AllData_Tsv_v100_GRCh37/CancerMutationCensus_AllData_v100_GRCh37_mutation_workflow_with_cdna.csv"  # "cosmic_cmc"  # file path to mutations csv/tsv file OR one of the supported databases
sequences = "/home/jrich/data/varseek_data_fresh/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.cdna.all.fa"  # cdna  # file path to reference sequence fasta file OR, only if 'mutations' is in the supported databases, one of the following options is also supported: "cds", "cdna", "genome", "cdna_and_genome" - sequences for gget mutate

# vk info
bowtie_path="/home/jrich/opt/bowtie2-2.5.4/bowtie2-2.5.4-linux-x86_64"
mutations_csv="/home/jrich/data/varseek_data_fresh/reference/cosmic/CancerMutationCensus_AllData_Tsv_v100_GRCh37/CancerMutationCensus_AllData_v100_GRCh37_with_cdna.csv"
reference_cdna_fasta="/home/jrich/data/varseek_data_fresh/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.cdna.all.fa"  # the one that matches up to mutation df annotations
reference_genome_fasta="/home/jrich/data/varseek_data_fresh/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa"  # the one that matches up to mutation df annotations
gtf_path="/home/jrich/data/varseek_data_fresh/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.87.gtf"  # the one that matches up to mutation df annotations

# %% [markdown]
# # Automatic variable initializations based on provided hyperparameters and paths

# %%
out_dir_notebook = os.path.join(out_dir_base, run_name)
reference_out_dir = os.path.join(out_dir_base, "reference")

os.makedirs(out_dir_base, exist_ok=True)
os.makedirs(out_dir_notebook, exist_ok=True)
os.makedirs(reference_out_dir, exist_ok=True)

if remove_Ns:
    max_ambiguous_vk = 0
else:
    max_ambiguous_vk = None

merge_identical_rc = not strandedness

vk_build_mcrs_fa_path = os.path.join(out_dir_notebook, "mcrs.fa")
update_df_out = os.path.join(out_dir_notebook, "mutation_metadata_df.csv")
os.makedirs(out_dir_notebook, exist_ok=True)

assert k >= w + 1, "k must be greater than or equal to w + 1"

id_to_header_csv=os.path.join(out_dir_notebook, "id_to_header_mapping.csv")
mutation_metadata_df_out_path_vk_info = os.path.join(out_dir_notebook, "mutation_metadata_df_updated_vk_info.csv")
mutation_metadata_df_exploded_path = os.path.join(out_dir_notebook, "mutation_metadata_df_updated_vk_info_exploded.csv") if save_exploded_df else None
mutation_index = f"{out_dir_notebook}/mutation_reference.idx"
dlist_fasta = f"{out_dir_notebook}/dlist.fa"
wt_mcrs_index = f"{out_dir_notebook}/wt_mcrs_reference.idx"


mcrs_fasta_vk_filter = os.path.join(out_dir_notebook, "mcrs_filtered.fa")
output_metadata_df_vk_filter = os.path.join(out_dir_notebook, "mutation_metadata_df_filtered.csv")
output_mutation_metadata_df_exploded_vk_filter = os.path.join(out_dir_notebook, "mutation_metadata_df_updated_vk_info_exploded_filtered.csv") if save_exploded_df else None
dlist_fasta_vk_filter = os.path.join(out_dir_notebook, "dlist_filtered.fa")
wt_mcrs_fa_vk_filter = os.path.join(out_dir_notebook, "mcrs_wt_filtered.fa")
t2g_vk_filter = os.path.join(out_dir_notebook, "t2g_filtered.txt")
t2g_wt_vk_filter = os.path.join(out_dir_notebook, "t2g_wt_filtered.txt")
id_to_header_csv_vk_filter = os.path.join(out_dir_notebook, "id_to_header_mapping_filtered.csv")

if dlist:
    dlist_kb_argument = dlist_fasta_vk_filter
else:
    dlist_kb_argument = "None"

# %% [markdown]
# # vk build

# %%
# %%time
vk.build(
    sequences=sequences,
    mutations=mutations,
    out=out_dir_notebook,
    reference_out=reference_out_dir,
    w=w,
    k=k,
    insertion_size_limit=insertion_size_limit,
    remove_seqs_with_wt_kmers=True,
    optimize_flanking_regions=True,
    min_seq_len=k,
    max_ambiguous=max_ambiguous_vk,
    merge_identical=True,
    merge_identical_rc=merge_identical_rc,
    cosmic_email = os.getenv('COSMIC_EMAIL'),
    cosmic_password = os.getenv('COSMIC_PASSWORD'),
    create_t2g=True,
    create_wt_mcrs_counterpart_fa=True,
    update_df=True,
    update_df_out=update_df_out,
    verbose=verbose,
)

# %% [markdown]
# # vk info

# %%
# %%time
vk.info(
    mutations = vk_build_mcrs_fa_path,
    updated_df=update_df_out,
    id_to_header_csv=id_to_header_csv,  # if none then assume no swapping occurred
    columns_to_include=columns_to_include,
    mcrs_id_column="mcrs_id",
    mcrs_sequence_column="mutant_sequence",
    mcrs_source_column="mcrs_source",  # if input df has concatenated cdna and header MCRS's, then I want to know whether it came from cdna or genome
    seqid_cdna_column="seq_ID",  # if input df has concatenated cdna and header MCRS's, then I want a way of mapping from cdna to genome  # TODO: implement these 4 column name arguments
    seqid_genome_column="chromosome",  # if input df has concatenated cdna and header MCRS's, then I want a way of mapping from cdna to genome
    mutation_cdna_column="mutation",  # if input df has concatenated cdna and header MCRS's, then I want a way of mapping from cdna to genome
    mutation_genome_column="mutation_genome",  # if input df has concatenated cdna and header MCRS's, then I want a way of mapping from cdna to genome
    gtf=gtf_path,  # for distance to nearest splice junction
    mutation_metadata_df_out_path=mutation_metadata_df_out_path_vk_info,
    out_dir_notebook=out_dir_notebook,
    reference_out_dir=reference_out_dir,
    dlist_reference_source=dlist_reference_source,
    ref_prefix="index",
    w=w,
    remove_Ns=remove_Ns,
    strandedness=strandedness,
    bowtie_path=bowtie_path,
    near_splice_junction_threshold=near_splice_junction_threshold,
    threads=threads,
    reference_cdna_fasta=reference_cdna_fasta,
    reference_genome_fasta=reference_genome_fasta,
    mutations_csv=mutations_csv,
    save_exploded_df=save_exploded_df,
    verbose=verbose,
)

# %% [markdown]
# # vk filter

# %%
# %%time
vk.filter(mutation_metadata_df_path = mutation_metadata_df_out_path_vk_info,
          mutation_metadata_df_exploded_path = mutation_metadata_df_exploded_path,
          output_mutation_metadata_df_exploded = output_mutation_metadata_df_exploded_vk_filter,
          output_mcrs_fasta=mcrs_fasta_vk_filter,
          output_metadata_df=output_metadata_df_vk_filter,
          dlist_fasta=dlist_fasta,
          output_dlist_fasta=dlist_fasta_vk_filter,
          output_wt_mcrs_fa=wt_mcrs_fa_vk_filter,
          create_t2g=True,
          output_t2g=t2g_vk_filter,
          output_t2g_wt=t2g_wt_vk_filter,
          id_to_header_csv=id_to_header_csv,
          output_id_to_header_csv=id_to_header_csv_vk_filter,
          verbose=True,
          return_df=False,
          filters = fasta_filters)

# %% [markdown]
# # kb ref

# %%
# %%time
if not os.path.exists(mutation_index):
    kb_ref_command = ["kb", "ref", "--workflow", "custom", "-t", str(threads), "-i", mutation_index, "--d-list", dlist_kb_argument, "-k", str(k), mcrs_fasta_vk_filter]
    subprocess.run(kb_ref_command, check=True)

if os.path.exists(wt_mcrs_fa_vk_filter) and not os.path.exists(mutation_index):
    kb_ref_command = ["kb", "ref", "--workflow", "custom", "-t", str(threads), "-i", wt_mcrs_index, "--d-list", dlist_kb_argument, "-k", str(k), wt_mcrs_fa_vk_filter]
    subprocess.run(kb_ref_command, check=True)

# %% [markdown]
# # Optional: kb ref on T2T reference genome

# %%
import os
import subprocess
out_dir_base = "/home/jrich/data/varseek_data_fresh"
reference_out_dir = os.path.join(out_dir_base, "reference")
threads = 16

from varseek.utils import download_t2t_reference_files
k_standard = 31
t2t_folder = f"{reference_out_dir}/T2T/GCF_009914755.1"
t2t_kb_folder = f"{t2t_folder}/kb_index"
standard_index = f"{t2t_kb_folder}/index.idx"
standard_t2g = f"{t2t_kb_folder}/t2g.txt"
standard_f1 = f"{t2t_kb_folder}/f1.fa"

if not os.path.exists(standard_index) or not os.path.exists(standard_t2g):
    os.makedirs(t2t_kb_folder, exist_ok=True)
    t2t_genome = f"{t2t_folder}/GCF_009914755.1_T2T-CHM13v2.0_genomic.fna"
    t2t_gtf = f"{t2t_folder}/genomic.gtf"
    
    if not os.path.exists(t2t_genome) or not os.path.exists(t2t_gtf):
        os.makedirs(t2t_folder, exist_ok=True)
        t2t_genome, t2t_cdna, t2t_gtf = download_t2t_reference_files(t2t_folder)

    kb_ref_standard_command = f"kb ref -k {k_standard} -i {standard_index} -g {standard_t2g} -f1 {standard_f1} -t {threads} {t2t_genome} {t2t_gtf}"
    result = subprocess.run(kb_ref_standard_command, shell=True, check=True)
# Out:
# [2024-11-18 11:24:46,790]    INFO [ref] Preparing /home/jrich/data/varseek_data_fresh/reference/T2T/GCF_009914755.1/GCF_009914755.1_T2T-CHM13v2.0_genomic.fna, /home/jrich/data/varseek_data_fresh/reference/T2T/GCF_009914755.1/genomic.gtf
# [2024-11-18 11:26:14,750] WARNING [main] Gene `SEPTIN14P14` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SEPTIN14P14`.
# [2024-11-18 11:26:14,750] WARNING [main] Gene `CICP3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CICP3`.
# [2024-11-18 11:26:14,750] WARNING [main] Gene `RNU6-1199P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1199P`.
# [2024-11-18 11:26:14,750] WARNING [main] Gene `TUBB8P11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TUBB8P11`.
# [2024-11-18 11:26:14,750] WARNING [main] Gene `RPL39P12` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL39P12`.
# [2024-11-18 11:26:14,750] WARNING [main] Gene `NDUFB4P8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `NDUFB4P8`.
# [2024-11-18 11:26:14,750] WARNING [main] Gene `RN7SL657P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL657P`.
# [2024-11-18 11:26:14,751] WARNING [main] Gene `LOC100288379` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100288379`.
# [2024-11-18 11:26:14,751] WARNING [main] Gene `LOC100129381` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100129381`.
# [2024-11-18 11:26:14,751] WARNING [main] Gene `LOC100420339` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100420339`.
# [2024-11-18 11:26:14,751] WARNING [main] Gene `RN7SL574P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL574P`.
# [2024-11-18 11:26:14,751] WARNING [main] Gene `EEF1DP6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `EEF1DP6`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RNU6-731P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-731P`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RPL37P9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL37P9`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RNU1-8P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-8P`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `TRUND-NNN4-1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRUND-NNN4-1`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RPL7AP18` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL7AP18`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `LOC100129776` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100129776`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RNU1-7P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-7P`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RNU6-991P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-991P`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RPL7P11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL7P11`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RPL7P7` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL7P7`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RPL27P3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL27P3`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RPL23AP19` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL23AP19`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RNU6-304P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-304P`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `HMGN2P17` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HMGN2P17`.
# [2024-11-18 11:26:14,752] WARNING [main] Gene `RN7SL451P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL451P`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RNA5SP40` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP40`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RPL9P11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL9P11`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RPL26P7` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL26P7`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `MZT1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MZT1P1`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RN7SKP269` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SKP269`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RPL21P21` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL21P21`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `PGAM1P11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PGAM1P11`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RNU6-828P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-828P`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RNU6-37P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-37P`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RN7SL731P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL731P`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RN7SL614P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL614P`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `HSPE1P24` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HSPE1P24`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `CFL1P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CFL1P6`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RNU6-537P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-537P`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RNU6-291P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-291P`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `RPL39P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL39P6`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `UBE2V2P3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `UBE2V2P3`.
# [2024-11-18 11:26:14,753] WARNING [main] Gene `MTCYBP45` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MTCYBP45`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `LOC101060126` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC101060126`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `SBF1P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SBF1P2`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RNU5E-4P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU5E-4P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RN7SL649P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL649P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RNU6-777P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-777P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RPL23AP89` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL23AP89`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RPL10P17` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL10P17`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `LOC124900427` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124900427`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `LOC124904680` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904680`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RNU6ATAC18P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6ATAC18P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `PRAMEF30P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRAMEF30P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RNU6-1072P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1072P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `PRAMEF29P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRAMEF29P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `PRAMEF31P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRAMEF31P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `PRAMEF35P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRAMEF35P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `LOC100132865` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100132865`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `PRAMEF32P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRAMEF32P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RNU6-771P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-771P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `BRWD1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `BRWD1P1`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RNA5SP41` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP41`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `RNU6-1265P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1265P`.
# [2024-11-18 11:26:14,754] WARNING [main] Gene `TBCAP2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TBCAP2`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `MFFP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MFFP1`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `ZBTB2P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ZBTB2P1`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `CHCHD2P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CHCHD2P6`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `LOC124904764` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904764`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `RNU7-179P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU7-179P`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `CD24P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CD24P1`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `RPL12P14` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL12P14`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `LOC124905656` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124905656`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `TBC1D3P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TBC1D3P6`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `FAM131C2P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `FAM131C2P`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `MT1XP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MT1XP1`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `RPL22P3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL22P3`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `RNU1-6P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-6P`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `PDE4DIPP8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PDE4DIPP8`.
# [2024-11-18 11:26:14,755] WARNING [main] Gene `LOC101056699` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC101056699`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `LOC128966612` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC128966612`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `TRV-CAC11-1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRV-CAC11-1`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `LOC124905576` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124905576`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `EIF1AXP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `EIF1AXP1`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `TRV-CAC13-1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRV-CAC13-1`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `LOC124905577` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124905577`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `CROCCP4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CROCCP4`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `PDE4DIPP9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PDE4DIPP9`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `TRV-CAC11-2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRV-CAC11-2`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `LOC124903860` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124903860`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `RNU1-5P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-5P`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `LOC107985101` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC107985101`.
# [2024-11-18 11:26:14,756] WARNING [main] Gene `DYNLL1P3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `DYNLL1P3`.
# [2024-11-18 11:26:14,757] WARNING [main] Gene `LOC124905702` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124905702`.
# [2024-11-18 11:26:14,757] WARNING [main] Gene `RNU6-1099P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1099P`.
# [2024-11-18 11:26:14,757] WARNING [main] Gene `RN7SL277P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL277P`.
# [2024-11-18 11:26:14,757] WARNING [main] Gene `RNU4-28P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU4-28P`.
# [2024-11-18 11:26:14,757] WARNING [main] Gene `RN7SL304P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL304P`.
# [2024-11-18 11:26:14,757] WARNING [main] Gene `LOC100419911` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100419911`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `RPS4XP4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS4XP4`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `RNU7-200P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU7-200P`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `RPS15AP6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS15AP6`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `HSPE1P27` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HSPE1P27`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `PPP1R11P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PPP1R11P1`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `PDE4DIPP10` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PDE4DIPP10`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `HS6ST1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HS6ST1P1`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `CROCCP5` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CROCCP5`.
# [2024-11-18 11:26:14,758] WARNING [main] Gene `PFN1P10` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PFN1P10`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `LOC124904736` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904736`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RPL21P29` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL21P29`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RN7SL386P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL386P`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RNU6-1022P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1022P`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RN7SL186P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL186P`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RNU6-776P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-776P`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `MPHOSPH6P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MPHOSPH6P1`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `PPIAP34` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PPIAP34`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RNU6-514P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-514P`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RNU6-135P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-135P`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RPL29P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL29P6`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `EEF1A1P48` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `EEF1A1P48`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `LOC124904841` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904841`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `BTBD6P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `BTBD6P1`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `H3P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `H3P1`.
# [2024-11-18 11:26:14,759] WARNING [main] Gene `RPL36P5` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL36P5`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `RPL26P8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL26P8`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `RNU6-1208P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1208P`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `IFITM3P7` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `IFITM3P7`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `SDHDP6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SDHDP6`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `LOC124904723` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904723`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `SDHDP7` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SDHDP7`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `SNRPFP2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SNRPFP2`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `RPL39P7` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL39P7`.
# [2024-11-18 11:26:14,760] WARNING [main] Gene `RNU6-110P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-110P`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `LOC100420494` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100420494`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `LOC124904684` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904684`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `MRPS6P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MRPS6P1`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RPL34P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL34P4`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RPL17P9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL17P9`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `DPPA2P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `DPPA2P2`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RN7SL679P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL679P`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RN7SL165P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL165P`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RPL12P13` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL12P13`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RPL32P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL32P6`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RPL18AP5` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL18AP5`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `CHCHD3P3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CHCHD3P3`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `NPM1P39` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `NPM1P39`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `SNRPEP7` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SNRPEP7`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RNU6-48P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-48P`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `LOC729973` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC729973`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RNU6-949P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-949P`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `CHMP1AP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CHMP1AP1`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RNU6-424P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-424P`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RPEP3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPEP3`.
# [2024-11-18 11:26:14,761] WARNING [main] Gene `RNU6-1245P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1245P`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RN7SL559P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL559P`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `SPCS2P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SPCS2P4`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `ARL8BP2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ARL8BP2`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RNU6-176P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-176P`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RNU7-29P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU7-29P`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RNU6ATAC27P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6ATAC27P`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `PRDX3P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRDX3P2`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RPL27P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL27P4`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RN7SKP91` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SKP91`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RN7SL371P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL371P`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `LOC107985097` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC107985097`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `SELENOWP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SELENOWP1`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RPL21P22` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL21P22`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `EEF1A1P46` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `EEF1A1P46`.
# [2024-11-18 11:26:14,762] WARNING [main] Gene `RNU6-40P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-40P`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `GAPDHP20` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `GAPDHP20`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `LRRC37A12P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LRRC37A12P`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `RN7SL122P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL122P`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `RPL18AP4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL18AP4`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `LOC100419257` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100419257`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `RN7SKP16` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SKP16`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `TLR12P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TLR12P`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `LOC100422287` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100422287`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `HSPD1P14` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HSPD1P14`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `RNA5SP42` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP42`.
# [2024-11-18 11:26:14,763] WARNING [main] Gene `LOC100420336` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100420336`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RPL12P45` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL12P45`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `EFCAB14P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `EFCAB14P1`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RN7SL503P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL503P`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RPL5P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL5P4`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RNY5P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNY5P1`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `LOC100419802` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100419802`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `CFAP97P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CFAP97P1`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `LOC100128093` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100128093`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RN7SL131P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL131P`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `UBE2V2P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `UBE2V2P4`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RNU4-27P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU4-27P`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `FTLP18` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `FTLP18`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RNU6-636P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-636P`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RNA5SP43` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP43`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RPS29P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS29P6`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `FTH1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `FTH1P1`.
# [2024-11-18 11:26:14,764] WARNING [main] Gene `RPS27P9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS27P9`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `ACTN4P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ACTN4P2`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `LOC100129497` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100129497`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RPS2P13` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS2P13`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNU6-584P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-584P`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNU6-510P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-510P`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `TUBB6P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TUBB6P1`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNU6-753P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-753P`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `HSPA5P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HSPA5P1`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNU6-605P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-605P`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `EIF1P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `EIF1P2`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNU6-608P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-608P`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNA5SP44` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP44`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `HSPE1P8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HSPE1P8`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `TRK-CTT12-1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRK-CTT12-1`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `LOC100128091` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100128091`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNU7-121P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU7-121P`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RPS2P12` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS2P12`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `OAZ1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OAZ1P1`.
# [2024-11-18 11:26:14,765] WARNING [main] Gene `RNU6-1237P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1237P`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RPL21P20` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL21P20`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `LOC100328982` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100328982`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `GTF2F2P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `GTF2F2P2`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RN7SL326P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL326P`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `LOC100128362` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100128362`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `UBE2V1P8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `UBE2V1P8`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RPL23AP17` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL23AP17`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RPL36AP9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL36AP9`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RNA5SP45` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP45`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `LOC100418723` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100418723`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `HNRNPFP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HNRNPFP1`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RPS15AP8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS15AP8`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RPS3AP11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS3AP11`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `TMSB4XP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TMSB4XP1`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `RNU6-536P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-536P`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `LOC100420252` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100420252`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `MKRN8P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MKRN8P`.
# [2024-11-18 11:26:14,766] WARNING [main] Gene `ATP6V1E1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ATP6V1E1P1`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `ATP6V0CP4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ATP6V0CP4`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `RNU6-880P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-880P`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `LOC124904715` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904715`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `RNA5SP46` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP46`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `LOC124904721` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904721`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `SHMT1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SHMT1P1`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `KRT8P47` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `KRT8P47`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `RN7SL479P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL479P`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `LOC100129492` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100129492`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `LOC100419796` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100419796`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `OOSP1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OOSP1P1`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `LOC100130714` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100130714`.
# [2024-11-18 11:26:14,767] WARNING [main] Gene `RNU6-369P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-369P`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `RPS15AP11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS15AP11`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `RNU5E-6P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU5E-6P`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `RNA5SP47` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP47`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `CCNB1IP1P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CCNB1IP1P1`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `PPIAP35` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PPIAP35`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `MRPS17P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MRPS17P1`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `OSTCP5` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OSTCP5`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `LOC124904849` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904849`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `PPIAP36` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PPIAP36`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `HMGB1P48` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HMGB1P48`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `RPL7AP16` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL7AP16`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `RPL6P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL6P1`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `TMA16P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TMA16P2`.
# [2024-11-18 11:26:14,768] WARNING [main] Gene `COX7BP4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `COX7BP4`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `NENFP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `NENFP1`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `TUBAP8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TUBAP8`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `CYP4A26P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CYP4A26P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `CYP4A43P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CYP4A43P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `CYP4A27P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CYP4A27P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `CYP4A44P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CYP4A44P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `TUBAP9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TUBAP9`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `MTND1P34` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MTND1P34`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `RPL21P24` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL21P24`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `ATP6V0E1P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ATP6V0E1P4`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `CYP46A4P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CYP46A4P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `PPP1R8P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PPP1R8P1`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `RNU6-723P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-723P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `LOC644462` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC644462`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `RNU4-61P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU4-61P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `RPL21P25` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL21P25`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `LOC124904851` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124904851`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `ZNF859P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ZNF859P`.
# [2024-11-18 11:26:14,769] WARNING [main] Gene `MTND2P29` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MTND2P29`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RPS2P11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS2P11`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `HMGB1P45` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HMGB1P45`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `FCF1P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `FCF1P6`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RNU6-1026P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1026P`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `PHB1P12` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PHB1P12`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `MRPS6P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `MRPS6P2`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `CFL1P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CFL1P2`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `LOC107985472` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC107985472`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RPS2P8` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS2P8`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `LOC100422413` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100422413`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RNU6-877P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-877P`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RNU6-1281P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1281P`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `GAPDHP51` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `GAPDHP51`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `SLC25A6P3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SLC25A6P3`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `TSEN15P2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TSEN15P2`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RNA5SP48` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNA5SP48`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RPS26P14` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPS26P14`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RN7SL290P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL290P`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `RN7SL788P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL788P`.
# [2024-11-18 11:26:14,770] WARNING [main] Gene `LOC100190934` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC100190934`.
# [2024-11-18 11:26:14,771] WARNING [main] Gene `LOC724060` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC724060`.
# ...
# [2024-11-18 11:26:15,798] WARNING [main] Gene `USP9YP35` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP35`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `CDY17P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY17P`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `ELOCP10` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ELOCP10`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `OFD1P12Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OFD1P12Y`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `TRAPPC2P10` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRAPPC2P10`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `RAB9AP5` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RAB9AP5`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `USP9YP12` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP12`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `RNU1-86P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-86P`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `USP9YP11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP11`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `USP9YP13` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP13`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `XKRYP4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `XKRYP4`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `CDY16P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY16P`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `CDY15P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY15P`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `ELOCP9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ELOCP9`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `OFD1P11Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OFD1P11Y`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `TRAPPC2P9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRAPPC2P9`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `RAB9AP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RAB9AP1`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `USP9YP29` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP29`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `RNU1-97P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-97P`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `USP9YP25` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP25`.
# [2024-11-18 11:26:15,798] WARNING [main] Gene `XKRYP3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `XKRYP3`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `PRYP3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRYP3`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `ELOCP16` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ELOCP16`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CDY14P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY14P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `USP9YP18` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP18`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `HSFY6P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HSFY6P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `OFD1P10Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OFD1P10Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `RBMY2CP` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RBMY2CP`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `PPP1R12BP2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PPP1R12BP2`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `TRIM60P11Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRIM60P11Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `ZNF736P2Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ZNF736P2Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `TRIM60P10Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRIM60P10Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `ZNF736P5Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ZNF736P5Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `ZNF736P4Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ZNF736P4Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `TRIM60P12Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRIM60P12Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `RBMY2YP` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RBMY2YP`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `RPL41P6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RPL41P6`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CICP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CICP1`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `LINC00265-3P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LINC00265-3P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `GOLGA6L13P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `GOLGA6L13P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `DNM1P27` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `DNM1P27`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `UBE2Q2P5Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `UBE2Q2P5Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `RN7SL725P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RN7SL725P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CHRFAM7AP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CHRFAM7AP1`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CSPG4P4Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CSPG4P4Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `DNM1P48` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `DNM1P48`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `DNM1P26` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `DNM1P26`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `GOLGA6L14P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `GOLGA6L14P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `GOLGA6L16P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `GOLGA6L16P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CDY19P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY19P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `USP9YP36` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP36`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `USP9YP33` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP33`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CDY20P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY20P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `ELOCP34` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ELOCP34`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `OFD1P13Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OFD1P13Y`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `TRAPPC2P5` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRAPPC2P5`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `RAB9AP2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RAB9AP2`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `USP9YP30` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP30`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `RNU1-107P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-107P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `USP9YP9` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP9`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `USP9YP19` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP19`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `XKRYP5` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `XKRYP5`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CDY21P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY21P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `CDY22P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY22P`.
# [2024-11-18 11:26:15,799] WARNING [main] Gene `ELOCP17` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ELOCP17`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `OFD1P14Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OFD1P14Y`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `OFD1P18Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OFD1P18Y`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `TRAPPC2P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRAPPC2P4`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `RAB9AP3` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RAB9AP3`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `USP9YP20` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP20`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `RNU1-40P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU1-40P`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `USP9YP21` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP21`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `XKRYP6` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `XKRYP6`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `PRYP4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PRYP4`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `ELOCP11` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ELOCP11`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `CDY23P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CDY23P`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `USP9YP26` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `USP9YP26`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `HSFY8P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `HSFY8P`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `OFD1P15Y` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `OFD1P15Y`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `RBMY2DP` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RBMY2DP`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `PPP1R12BP1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PPP1R12BP1`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `RNU6-1314P` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `RNU6-1314P`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `CYCSP48` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CYCSP48`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `ANKRD36P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ANKRD36P1`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `LOC124905308` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124905308`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `CYCSP49` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CYCSP49`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `TPTE2P4` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TPTE2P4`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `SLC25A15P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `SLC25A15P1`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `PARP4P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `PARP4P1`.
# [2024-11-18 11:26:15,800] WARNING [main] Gene `CCNQP2` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CCNQP2`.
# [2024-11-18 11:26:15,806] WARNING [main] Gene `CTBP2P1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `CTBP2P1`.
# [2024-11-18 11:26:15,807] WARNING [main] Gene `LOC124908904_1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124908904_1`.
# [2024-11-18 11:26:15,807] WARNING [main] Gene `AMD1P2_1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `AMD1P2_1`.
# [2024-11-18 11:26:15,807] WARNING [main] Gene `DPH3P2_1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `DPH3P2_1`.
# [2024-11-18 11:26:15,807] WARNING [main] Gene `LOC124905309` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `LOC124905309`.
# [2024-11-18 11:26:15,807] WARNING [main] Gene `ELOCP24_1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `ELOCP24_1`.
# [2024-11-18 11:26:15,807] WARNING [main] Gene `TRPC6P1_1` has no transcripts. The entire gene will be marked as a transcript and an exon with ID `TRPC6P1_1`.
# [2024-11-18 11:26:23,192]    INFO [ref] Splitting genome /home/jrich/data/varseek_data_fresh/reference/T2T/GCF_009914755.1/GCF_009914755.1_T2T-CHM13v2.0_genomic.fna into cDNA at /home/jrich/Desktop/varseek/notebooks/tmp/tmp16l0fid_
# [2024-11-18 11:27:46,491]    INFO [ref] Concatenating 1 cDNAs to /home/jrich/data/varseek_data_fresh/reference/T2T/GCF_009914755.1/kb_index/f1.fa
# [2024-11-18 11:27:48,107]    INFO [ref] Creating transcript-to-gene mapping at /home/jrich/data/varseek_data_fresh/reference/T2T/GCF_009914755.1/kb_index/t2g.txt
# [2024-11-18 11:27:50,286]    INFO [ref] Indexing /home/jrich/data/varseek_data_fresh/reference/T2T/GCF_009914755.1/kb_index/f1.fa to /home/jrich/data/varseek_data_fresh/reference/T2T/GCF_009914755.1/kb_index/index.idx
