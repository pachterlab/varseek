# %% [markdown]
# Workflow followed according to: https://gatk.broadinstitute.org/hc/en-us/articles/360035531192-RNAseq-short-variant-discovery-SNPs-Indels
#
# Github workflow for GATK4 here: https://github.com/gatk-workflows/gatk4-rnaseq-germline-snps-indels/blob/master/gatk4-rna-best-practices.wdl

# %%
import os
import pysam
import pandas as pd
from tqdm import tqdm
from varseek.utils import calculate_metrics, draw_confusion_matrix, create_venn_diagram, calculate_sensitivity_specificity, create_stratified_metric_bar_plot, add_vcf_info_to_cosmic_tsv, merge_gatk_and_cosmic

# %%
import random

def generate_random_fastq(output_path, num_sequences=5000, seq_length=150, quality_score="I"):
    if not os.path.exists(output_path):
        if not os.path.exists(os.path.dirname(output_path)):
            os.makedirs(os.path.dirname(output_path))
        bases = ['A', 'C', 'G', 'T']
        with open(output_path, "w") as fastq_file:
            for i in range(num_sequences):
                # Generate a random sequence of the specified length
                sequence = ''.join(random.choices(bases, k=seq_length))
                
                # Create a quality string of the same length, filled with the specified quality score
                quality = quality_score * seq_length
                
                # Write the FASTQ entry
                fastq_file.write(f"@seq_{i + 1}\n")
                fastq_file.write(f"{sequence}\n")
                fastq_file.write("+\n")
                fastq_file.write(f"{quality}\n")

# %%
synthetic_read_fastq = "/home/jrich/data/varseek_data_fresh/manuscript_worthy/vk_sim_2024dec9_complex_testing/synthetic_reads.fq"  #!!! update path
unique_mcrs_df_path = "/home/jrich/data/varseek_data_fresh/manuscript_worthy/vk_sim_2024dec9_complex_testing/unique_mcrs_df.csv"  #!!! update path
gatk_parent = "/home/jrich/data/varseek_data/gatk_dec20"  #!!! update for each run
# generate_random_fastq(synthetic_read_fastq)

threads = 32
read_length = 150
mutation_source = "cdna"  # "cdna", "cds"
mark_duplicates = False
apply_bqsr = False
apply_mutation_filters = False

cosmic_tsv = "/home/jrich/data/varseek_data/reference/cosmic/CancerMutationCensus_AllData_Tsv_v100_GRCh37/CancerMutationCensus_AllData_v100_GRCh37.tsv"
cosmic_cdna_info_csv = "/home/jrich/data/varseek_data/reference/cosmic/CancerMutationCensus_AllData_Tsv_v100_GRCh37/CancerMutationCensus_AllData_v100_GRCh37_mutation_workflow_with_cdna.csv"

# if these paths don't exist then they will be created
reference_genome_fasta = "/home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa"
reference_genome_gtf = "/home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.87.gtf"
genomes1000_vcf = "/home/jrich/data/varseek_data/reference/ensembl_grch37_release93/1000GENOMES-phase_3.vcf"
ensembl_germline_vcf = "/home/jrich/data/varseek_data/reference/ensembl_grch37_release93/homo_sapiens.vcf"
star_genome_dir = "/home/jrich/data/varseek_data/reference/ensembl_grch37_release93/star_reference"

STAR = "/home/jrich/opt/STAR-2.7.11b/source/STAR"
java = "/home/jrich/opt/java/jdk-17.0.12+7/bin/java"
picard_jar = "/home/jrich/opt/picard/build/libs/picard.jar"
gatk = "/home/jrich/opt/gatk-4.6.0.0/gatk"

# %%
java_home = os.path.dirname(os.path.dirname(java))

os.environ['JAVA_HOME'] = java_home
os.environ['PATH'] = f"{os.environ['JAVA_HOME']}/bin:" + os.environ['PATH']

os.makedirs(star_genome_dir, exist_ok=True)

alignment_folder = f"{gatk_parent}/alignment"
os.makedirs(alignment_folder, exist_ok=True)

gatk_supporting_files = f"{gatk_parent}/supporting_files"
os.makedirs(gatk_supporting_files, exist_ok=True)

plot_output_folder = f"{gatk_parent}/plots"
os.makedirs(plot_output_folder, exist_ok=True)

ensembl_germline_vcf_filtered = ensembl_germline_vcf.replace(".vcf", "_filtered.vcf")

out_file_name_prefix = f"{alignment_folder}/sample_"

vcf_folder = f"{gatk_parent}/vcfs"
haplotypecaller_folder = f"{vcf_folder}/haplotypecaller"
mutect2_folder = f"{vcf_folder}/mutect2"

os.makedirs(vcf_folder, exist_ok=True)
os.makedirs(haplotypecaller_folder, exist_ok=True)
os.makedirs(mutect2_folder, exist_ok=True)

aligned_and_unmapped_bam = f"{out_file_name_prefix}Aligned.sortedByCoord.out.bam"
aligned_only_bam = f"{alignment_folder}/aligned_only.bam"
unmapped_bam = f"{alignment_folder}/unmapped.bam"
merged_bam = f"{alignment_folder}/merged.bam"

marked_duplicates_bam = f"{alignment_folder}/marked_duplicates.bam" if mark_duplicates else merged_bam
marked_dup_metrics_txt = f"{alignment_folder}/marked_dup_metrics.txt"


split_n_cigar_reads_bam = f"{alignment_folder}/split_n_cigar_reads.bam"
recal_data_table = f"{alignment_folder}/recal_data.table"
recalibrated_bam = f"{alignment_folder}/recalibrated.bam" if apply_bqsr else split_n_cigar_reads_bam
covariates_plot = f"{alignment_folder}/AnalyzeCovariates.pdf"
haplotypecaller_unfiltered_vcf = f"{haplotypecaller_folder}/haplotypecaller_output_unfiltered.g.vcf.gz"

haplotypecaller_filtered_vcf = f"{haplotypecaller_folder}/haplotypecaller_output_filtered.vcf.gz"
haplotypecaller_filtered_applied_vcf = f"{haplotypecaller_folder}/haplotypecaller_output_filtered_applied.vcf.gz"

panel_of_normals_vcf = f"{gatk_supporting_files}/1000g_pon.hg38.vcf.gz"
panel_of_normals_vcf_filtered = f"{gatk_supporting_files}/1000g_pon.hg38_filtered.vcf.gz"
mutect2_unfiltered_vcf = f"{mutect2_folder}/mutect2_output_unfiltered.g.vcf.gz"
mutect2_filtered_vcf = f"{mutect2_folder}/mutect2_output_filtered.vcf.gz"
mutect2_filtered_applied_vcf = f"{mutect2_folder}/mutect2_output_filtered_applied.vcf.gz"

if apply_mutation_filters:
    haplotypecaller_vcf_final = haplotypecaller_filtered_applied_vcf
    mutect2_vcf_final = mutect2_filtered_applied_vcf
else:
    haplotypecaller_vcf_final = haplotypecaller_unfiltered_vcf
    mutect2_vcf_final = mutect2_unfiltered_vcf

# %%
if not os.path.exists(reference_genome_fasta):
    # !wget -O {reference_genome_fasta}.gz https://ftp.ensembl.org/pub/grch37/release-93/fasta/homo_sapiens/dna/Homo_sapiens.GRCh37.dna.primary_assembly.fa.gz && gunzip {reference_genome_fasta}.gz

if not os.path.exists(reference_genome_gtf):
    # !wget -O {reference_genome_gtf}.gz https://ftp.ensembl.org/pub/grch37/release-93/gtf/homo_sapiens/Homo_sapiens.GRCh37.87.gtf.gz && gunzip {reference_genome_gtf}.gz

if not os.path.exists(genomes1000_vcf):
    # !wget -O {genomes1000_vcf}.gz https://ftp.ensembl.org/pub/grch37/release-93/variation/vcf/homo_sapiens/1000GENOMES-phase_3.vcf.gz && gunzip {genomes1000_vcf}.gz
    
if not os.path.exists(ensembl_germline_vcf):
    # !wget -O {ensembl_germline_vcf}.gz https://ftp.ensembl.org/pub/grch37/release-93/variation/vcf/homo_sapiens/homo_sapiens.vcf.gz && gunzip {ensembl_germline_vcf}.gz

if not os.path.exists(ensembl_germline_vcf_filtered):
    ensembl_germline_vcf_temp1 = ensembl_germline_vcf.replace(".vcf", "_temp1.vcf")
    # ensembl_germline_vcf_temp2 = ensembl_germline_vcf.replace(".vcf", "_temp2.vcf")
    # !grep -vP '^[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*[WH]|^[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*[WH]' $ensembl_germline_vcf > $ensembl_germline_vcf_temp1
    # !grep -vP '^[^\t]*\t[^\t]*\t[^\t]*\t\t|^[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t\t' $ensembl_germline_vcf_temp1 > $ensembl_germline_vcf_filtered
    # !rm $ensembl_germline_vcf_temp1

# if not os.path.exists(panel_of_normals_vcf):
#     !wget -P {gatk_supporting_files} https://storage.googleapis.com/gatk-best-practices/somatic-hg38/1000g_pon.hg38.vcf.gz
#     !wget -P {gatk_supporting_files} https://storage.googleapis.com/gatk-best-practices/somatic-hg38/1000g_pon.hg38.vcf.gz.tbi

# if not os.path.exists(panel_of_normals_vcf_filtered):
#     decompressed_pon_vcf = panel_of_normals_vcf.replace(".vcf.gz", ".vcf")
#     !gunzip -c $panel_of_normals_vcf > $decompressed_pon_vcf
    
#     # Remove 'chr' prefix from data lines
#     !sed -i 's/^chr//' $decompressed_pon_vcf

#     # Remove 'chr' prefix from contig headers in the VCF
#     !sed -i '/^##contig/s/ID=chr/ID=/' $decompressed_pon_vcf

#     # gunzip again
#     !bgzip -c $decompressed_pon_vcf > $panel_of_normals_vcf_filtered  # TODO: get bgzip installed

# %% [markdown]
# 1. Mapping to the Reference with STAR

# %%
read_length_minus_one = read_length - 1

if not os.listdir(star_genome_dir):
    # !$STAR \
        --runThreadN $threads \
        --runMode genomeGenerate \
        --genomeDir $star_genome_dir \
        --genomeFastaFiles $reference_genome_fasta \
        --sjdbGTFfile $reference_genome_gtf \
        --sjdbOverhang $read_length_minus_one

# %%
#* --outSAMmapqUnique 60 - changed from default of 255 to avoid colliding with some aligners' use of 255 as a special value

# !$STAR \
    --runThreadN $threads \
    --genomeDir $star_genome_dir \
    --readFilesIn $synthetic_read_fastq \
    --sjdbOverhang $read_length_minus_one \
    --outFileNamePrefix $out_file_name_prefix \
    --outSAMtype BAM SortedByCoordinate \
    --outSAMunmapped Within \
    --outSAMmapqUnique 60 \
    --twopassMode Basic
# Out:
# 	/home/jrich/opt/STAR-2.7.11b/source/STAR --runThreadN 32 --genomeDir /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/star_reference --readFilesIn /home/jrich/data/varseek_data_fresh/vk_sim_2024dec9_complex_testing/synthetic_reads.fq --sjdbOverhang 149 --outFileNamePrefix /home/jrich/data/varseek_data/gatk_dec17/alignment/sample_ --outSAMtype BAM SortedByCoordinate --outSAMunmapped Within --outSAMmapqUnique 60 --twopassMode Basic
# 	STAR version: 2.7.11b   compiled: 2024-07-22T09:22:47-0700 dator:/home/jrich/opt/STAR-2.7.11b/source
# Dec 17 11:31:25 ..... started STAR run
# Dec 17 11:31:25 ..... loading genome
# Dec 17 11:32:02 ..... started 1st pass mapping
# Dec 17 11:32:41 ..... finished 1st pass mapping
# Dec 17 11:32:42 ..... inserting junctions into the genome indices
# Dec 17 11:34:23 ..... started mapping
# Dec 17 11:34:58 ..... finished mapping
# Dec 17 11:35:03 ..... started sorting BAM
# Dec 17 11:35:16 ..... finished successfully

# %% [markdown]
# Separate unmapped reads into its own BAM file

# %%
# with pysam.AlignmentFile(aligned_and_unmapped_bam, "rb") as bam_in: 
#     # unmapped_header = bam_in.header.to_dict()
#     # if 'PG' in unmapped_header:
#     #     del unmapped_header['PG']
           
#     with pysam.AlignmentFile(aligned_only_bam, "wb", template=bam_in) as bam_aligned_out, pysam.AlignmentFile(unmapped_bam, "wb", template=bam_in) as bam_unmapped_out:
#         for read in bam_in:
#             if read.is_unmapped:
#                 bam_unmapped_out.write(read)  # Write unmapped read to the unmapped BAM file
#             else:
#                 bam_aligned_out.write(read)  # Write aligned read to the aligned BAM file

# print(f"Unmapped reads written to {unmapped_bam}")

#

# %%
# !$java -jar $picard_jar FastqToSam \
    -FASTQ $synthetic_read_fastq \
    -OUTPUT $unmapped_bam \
    -READ_GROUP_NAME rg1 \
    -SAMPLE_NAME sample1 \
    -LIBRARY_NAME lib1 \
    -PLATFORM_UNIT unit1 \
    -PLATFORM ILLUMINA \
    -SEQUENCING_CENTER center1
# Out:
# 11:35:22.778 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/picard/build/libs/picard.jar!/com/intel/gkl/native/libgkl_compression.so
# [Tue Dec 17 11:35:22 PST 2024] FastqToSam --FASTQ /home/jrich/data/varseek_data_fresh/vk_sim_2024dec9_complex_testing/synthetic_reads.fq --OUTPUT /home/jrich/data/varseek_data/gatk_dec17/alignment/unmapped.bam --READ_GROUP_NAME rg1 --SAMPLE_NAME sample1 --LIBRARY_NAME lib1 --PLATFORM_UNIT unit1 --PLATFORM ILLUMINA --SEQUENCING_CENTER center1 --USE_SEQUENTIAL_FASTQS false --SORT_ORDER queryname --MIN_Q 0 --MAX_Q 93 --STRIP_UNPAIRED_MATE_NUMBER false --ALLOW_AND_IGNORE_EMPTY_LINES false --ALLOW_EMPTY_FASTQ false --VERBOSITY INFO --QUIET false --VALIDATION_STRINGENCY STRICT --COMPRESSION_LEVEL 5 --MAX_RECORDS_IN_RAM 500000 --CREATE_INDEX false --CREATE_MD5_FILE false --help false --version false --showHidden false --USE_JDK_DEFLATER false --USE_JDK_INFLATER false
# [Tue Dec 17 11:35:22 PST 2024] Executing as jrich@dator on Linux 3.10.0-1127.13.1.el7.x86_64 amd64; OpenJDK 64-Bit Server VM 17.0.12+7; Deflater: Intel; Inflater: Intel; Provider GCS is available; Picard version: Version:3.2.0-4-ge0475183b-SNAPSHOT
# WARNING	2024-12-17 11:35:23	FastqToSam	Making ambiguous determination about fastq's quality encoding; more than one format possible based on observed qualities.
# INFO	2024-12-17 11:35:23	FastqToSam	Auto-detected quality format as: Illumina.
# INFO	2024-12-17 11:35:26	FastqToSam	Processed     1,000,000 records.  Elapsed time: 00:00:03s.  Time for last 1,000,000:    3s.  Last read position: */*
# INFO	2024-12-17 11:35:30	FastqToSam	Processed     2,000,000 records.  Elapsed time: 00:00:06s.  Time for last 1,000,000:    3s.  Last read position: */*
# INFO	2024-12-17 11:35:32	FastqToSam	Processed     3,000,000 records.  Elapsed time: 00:00:09s.  Time for last 1,000,000:    2s.  Last read position: */*
# INFO	2024-12-17 11:35:36	FastqToSam	Processed     4,000,000 records.  Elapsed time: 00:00:13s.  Time for last 1,000,000:    3s.  Last read position: */*
# INFO	2024-12-17 11:35:39	FastqToSam	Processed     5,000,000 records.  Elapsed time: 00:00:16s.  Time for last 1,000,000:    3s.  Last read position: */*
# INFO	2024-12-17 11:35:42	FastqToSam	Processed     6,000,000 records.  Elapsed time: 00:00:19s.  Time for last 1,000,000:    2s.  Last read position: */*
# INFO	2024-12-17 11:35:45	FastqToSam	Processed     7,000,000 records.  Elapsed time: 00:00:22s.  Time for last 1,000,000:    3s.  Last read position: */*
# INFO	2024-12-17 11:35:48	FastqToSam	Processed     8,000,000 records.  Elapsed time: 00:00:25s.  Time for last 1,000,000:    2s.  Last read position: */*
# INFO	2024-12-17 11:35:51	FastqToSam	Processed     9,000,000 records.  Elapsed time: 00:00:28s.  Time for last 1,000,000:    3s.  Last read position: */*
# INFO	2024-12-17 11:35:54	FastqToSam	Processed    10,000,000 records.  Elapsed time: 00:00:31s.  Time for last 1,000,000:    3s.  Last read position: */*
# INFO	2024-12-17 11:35:57	FastqToSam	Processed    11,000,000 records.  Elapsed time: 00:00:34s.  Time for last 1,000,000:    2s.  Last read position: */*
# INFO	2024-12-17 11:35:59	FastqToSam	Processed    12,000,000 records.  Elapsed time: 00:00:36s.  Time for last 1,000,000:    2s.  Last read position: */*
# INFO	2024-12-17 11:36:01	FastqToSam	Processed 12592654 fastq reads
# [Tue Dec 17 11:36:28 PST 2024] picard.sam.FastqToSam done. Elapsed time: 1.10 minutes.
# Runtime.totalMemory()=1929379840

# %% [markdown]
# 2. MergeBamAlignment

# %%
reference_genome_dict = reference_genome_fasta.replace(".fa", ".dict")

# !$java -jar $picard_jar CreateSequenceDictionary \
    -R $reference_genome_fasta \
    -O $reference_genome_dict
# Out:
# 11:36:30.223 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/picard/build/libs/picard.jar!/com/intel/gkl/native/libgkl_compression.so
# [Tue Dec 17 11:36:30 PST 2024] CreateSequenceDictionary --OUTPUT /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.dict --REFERENCE /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa --TRUNCATE_NAMES_AT_WHITESPACE true --NUM_SEQUENCES 2147483647 --VERBOSITY INFO --QUIET false --VALIDATION_STRINGENCY STRICT --COMPRESSION_LEVEL 5 --MAX_RECORDS_IN_RAM 500000 --CREATE_INDEX false --CREATE_MD5_FILE false --help false --version false --showHidden false --USE_JDK_DEFLATER false --USE_JDK_INFLATER false
# [Tue Dec 17 11:36:30 PST 2024] Executing as jrich@dator on Linux 3.10.0-1127.13.1.el7.x86_64 amd64; OpenJDK 64-Bit Server VM 17.0.12+7; Deflater: Intel; Inflater: Intel; Provider GCS is available; Picard version: Version:3.2.0-4-ge0475183b-SNAPSHOT
# [Tue Dec 17 11:36:30 PST 2024] picard.sam.CreateSequenceDictionary done. Elapsed time: 0.00 minutes.
# Runtime.totalMemory()=2181038080
# To get help, see http://broadinstitute.github.io/picard/index.html#GettingHelp
# Exception in thread "main" picard.PicardException: file:///home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.dict already exists.  Delete this file and try again, or specify a different output file.
# 	at picard.sam.CreateSequenceDictionary.doWork(CreateSequenceDictionary.java:227)
# 	at picard.cmdline.CommandLineProgram.instanceMain(CommandLineProgram.java:281)
# 	at picard.cmdline.PicardCommandLine.instanceMain(PicardCommandLine.java:105)
# 	at picard.cmdline.PicardCommandLine.main(PicardCommandLine.java:115)

# %%
# !$java -jar $picard_jar MergeBamAlignment \
    --ALIGNED_BAM $aligned_and_unmapped_bam \
    --UNMAPPED_BAM $unmapped_bam \
    --OUTPUT $merged_bam \
    --REFERENCE_SEQUENCE $reference_genome_fasta \
    --SORT_ORDER coordinate \
    --INCLUDE_SECONDARY_ALIGNMENTS false \
    --VALIDATION_STRINGENCY SILENT
# Out:
# 11:36:31.371 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/picard/build/libs/picard.jar!/com/intel/gkl/native/libgkl_compression.so
# [Tue Dec 17 11:36:31 PST 2024] MergeBamAlignment --UNMAPPED_BAM /home/jrich/data/varseek_data/gatk_dec17/alignment/unmapped.bam --ALIGNED_BAM /home/jrich/data/varseek_data/gatk_dec17/alignment/sample_Aligned.sortedByCoord.out.bam --OUTPUT /home/jrich/data/varseek_data/gatk_dec17/alignment/merged.bam --SORT_ORDER coordinate --INCLUDE_SECONDARY_ALIGNMENTS false --VALIDATION_STRINGENCY SILENT --REFERENCE_SEQUENCE /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa --ADD_PG_TAG_TO_READS true --PAIRED_RUN true --CLIP_ADAPTERS true --IS_BISULFITE_SEQUENCE false --ALIGNED_READS_ONLY false --MAX_INSERTIONS_OR_DELETIONS 1 --ATTRIBUTES_TO_REVERSE OQ --ATTRIBUTES_TO_REVERSE U2 --ATTRIBUTES_TO_REVERSE_COMPLEMENT E2 --ATTRIBUTES_TO_REVERSE_COMPLEMENT SQ --READ1_TRIM 0 --READ2_TRIM 0 --ALIGNER_PROPER_PAIR_FLAGS false --PRIMARY_ALIGNMENT_STRATEGY BestMapq --CLIP_OVERLAPPING_READS true --HARD_CLIP_OVERLAPPING_READS false --ADD_MATE_CIGAR true --UNMAP_CONTAMINANT_READS false --MIN_UNCLIPPED_BASES 32 --MATCHING_DICTIONARY_TAGS M5 --MATCHING_DICTIONARY_TAGS LN --UNMAPPED_READ_STRATEGY DO_NOT_CHANGE --VERBOSITY INFO --QUIET false --COMPRESSION_LEVEL 5 --MAX_RECORDS_IN_RAM 500000 --CREATE_INDEX false --CREATE_MD5_FILE false --help false --version false --showHidden false --USE_JDK_DEFLATER false --USE_JDK_INFLATER false
# [Tue Dec 17 11:36:31 PST 2024] Executing as jrich@dator on Linux 3.10.0-1127.13.1.el7.x86_64 amd64; OpenJDK 64-Bit Server VM 17.0.12+7; Deflater: Intel; Inflater: Intel; Provider GCS is available; Picard version: Version:3.2.0-4-ge0475183b-SNAPSHOT
# INFO	2024-12-17 11:36:31	SamAlignmentMerger	Processing SAM file(s): [/home/jrich/data/varseek_data/gatk_dec17/alignment/sample_Aligned.sortedByCoord.out.bam]
# WARNING	2024-12-17 11:36:31	SamAlignmentMerger	Exception merging bam alignment - attempting to sort aligned reads and try again: Underlying iterator is not queryname sorted: vcrs_1252553_38fM 150b aligned to 1:16661-16889. > vcrs_1252553_33fM 150b aligned to 1:16666-16894.
# INFO	2024-12-17 11:36:34	SamAlignmentMerger	Read 1000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:36	SamAlignmentMerger	Read 2000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:38	SamAlignmentMerger	Read 3000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:39	SamAlignmentMerger	Read 4000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:41	SamAlignmentMerger	Read 5000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:42	SamAlignmentMerger	Read 6000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:44	SamAlignmentMerger	Read 7000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:45	SamAlignmentMerger	Read 8000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:47	SamAlignmentMerger	Read 9000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:48	SamAlignmentMerger	Read 10000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:50	SamAlignmentMerger	Read 11000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:51	SamAlignmentMerger	Read 12000000 records from alignment SAM/BAM.
# INFO	2024-12-17 11:36:53	SamAlignmentMerger	Finished reading 12862585 total records from alignment SAM/BAM.
# INFO	2024-12-17 11:37:02	AbstractAlignmentMerger	Merged     1,000,000 records.  Elapsed time: 00:00:31s.  Time for last 1,000,000:   31s.  Last read position: 9:131,038,435.  Last read name: vcrs_0631196_28rW
# INFO	2024-12-17 11:37:09	AbstractAlignmentMerger	Merged     2,000,000 records.  Elapsed time: 00:00:38s.  Time for last 1,000,000:    7s.  Last read position: 12:10,978,233.  Last read name: vcrs_1266600_2rW
# INFO	2024-12-17 11:37:15	AbstractAlignmentMerger	Merged     3,000,000 records.  Elapsed time: 00:00:44s.  Time for last 1,000,000:    5s.  Last read position: 6:89,856,261.  Last read name: vcrs_1898845_30rM
# INFO	2024-12-17 11:37:21	AbstractAlignmentMerger	Merged     4,000,000 records.  Elapsed time: 00:00:50s.  Time for last 1,000,000:    6s.  Last read position: 4:186,067,969.  Last read name: vcrs_2536945_41fW
# INFO	2024-12-17 11:37:27	AbstractAlignmentMerger	Merged     5,000,000 records.  Elapsed time: 00:00:55s.  Time for last 1,000,000:    5s.  Last read position: 20:31,020,696.  Last read name: vcrs_3165719_13fW
# INFO	2024-12-17 11:37:33	AbstractAlignmentMerger	Merged     6,000,000 records.  Elapsed time: 00:01:02s.  Time for last 1,000,000:    6s.  Last read position: 17:33,680,486.  Last read name: vcrs_3814281_44fM
# INFO	2024-12-17 11:37:40	AbstractAlignmentMerger	Merged     7,000,000 records.  Elapsed time: 00:01:08s.  Time for last 1,000,000:    6s.  Last read position: X:123,210,261.  Last read name: vcrs_4466162_3fW
# INFO	2024-12-17 11:37:45	AbstractAlignmentMerger	Merged     8,000,000 records.  Elapsed time: 00:01:13s.  Time for last 1,000,000:    5s.  Last read position: X:153,176,186.  Last read name: vcrs_5112749_27rM
# INFO	2024-12-17 11:37:51	AbstractAlignmentMerger	Merged     9,000,000 records.  Elapsed time: 00:01:20s.  Time for last 1,000,000:    6s.  Last read position: 11:111,425,932.  Last read name: vcrs_5221479_31fM
# INFO	2024-12-17 11:38:59	AbstractAlignmentMerger	Written in coordinate order to output    10,000,000 records.  Elapsed time: 00:01:03s.  Time for last 10,000,000:   62s.  Last read position: */*
# INFO	2024-12-17 11:39:05	AbstractAlignmentMerger	Wrote 12830220 alignment records and 2874562 unmapped reads.
# [Tue Dec 17 11:39:05 PST 2024] picard.sam.MergeBamAlignment done. Elapsed time: 2.57 minutes.
# Runtime.totalMemory()=1962934272

# %% [markdown]
# 3. MarkDuplicates

# %%
if mark_duplicates:
      # !$java -jar $picard_jar MarkDuplicates \
            --INPUT $merged_bam \
            --OUTPUT $marked_duplicates_bam \
            --METRICS_FILE $marked_dup_metrics_txt \
            --CREATE_INDEX true \
            --VALIDATION_STRINGENCY SILENT
# Out:
# 11:39:06.879 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/picard/build/libs/picard.jar!/com/intel/gkl/native/libgkl_compression.so
# [Tue Dec 17 11:39:06 PST 2024] MarkDuplicates --INPUT /home/jrich/data/varseek_data/gatk_dec17/alignment/merged.bam --OUTPUT /home/jrich/data/varseek_data/gatk_dec17/alignment/marked_duplicates.bam --METRICS_FILE /home/jrich/data/varseek_data/gatk_dec17/alignment/marked_dup_metrics.txt --VALIDATION_STRINGENCY SILENT --CREATE_INDEX true --MAX_SEQUENCES_FOR_DISK_READ_ENDS_MAP 50000 --MAX_FILE_HANDLES_FOR_READ_ENDS_MAP 8000 --SORTING_COLLECTION_SIZE_RATIO 0.25 --TAG_DUPLICATE_SET_MEMBERS false --REMOVE_SEQUENCING_DUPLICATES false --TAGGING_POLICY DontTag --CLEAR_DT true --DUPLEX_UMI false --FLOW_MODE false --FLOW_DUP_STRATEGY FLOW_QUALITY_SUM_STRATEGY --USE_END_IN_UNPAIRED_READS false --USE_UNPAIRED_CLIPPED_END false --UNPAIRED_END_UNCERTAINTY 0 --UNPAIRED_START_UNCERTAINTY 0 --FLOW_SKIP_FIRST_N_FLOWS 0 --FLOW_Q_IS_KNOWN_END false --FLOW_EFFECTIVE_QUALITY_THRESHOLD 15 --ADD_PG_TAG_TO_READS true --REMOVE_DUPLICATES false --ASSUME_SORTED false --DUPLICATE_SCORING_STRATEGY SUM_OF_BASE_QUALITIES --PROGRAM_RECORD_ID MarkDuplicates --PROGRAM_GROUP_NAME MarkDuplicates --READ_NAME_REGEX <optimized capture of last three ':' separated fields as numeric values> --OPTICAL_DUPLICATE_PIXEL_DISTANCE 100 --MAX_OPTICAL_DUPLICATE_SET_SIZE 300000 --VERBOSITY INFO --QUIET false --COMPRESSION_LEVEL 5 --MAX_RECORDS_IN_RAM 500000 --CREATE_MD5_FILE false --help false --version false --showHidden false --USE_JDK_DEFLATER false --USE_JDK_INFLATER false
# [Tue Dec 17 11:39:07 PST 2024] Executing as jrich@dator on Linux 3.10.0-1127.13.1.el7.x86_64 amd64; OpenJDK 64-Bit Server VM 17.0.12+7; Deflater: Intel; Inflater: Intel; Provider GCS is available; Picard version: Version:3.2.0-4-ge0475183b-SNAPSHOT
# INFO	2024-12-17 11:39:07	MarkDuplicates	Start of doWork freeMemory: 377794000; totalMemory: 402653184; maxMemory: 32178700288
# INFO	2024-12-17 11:39:07	MarkDuplicates	Reading input file and constructing read end information.
# INFO	2024-12-17 11:39:07	MarkDuplicates	Will retain up to 116589493 data points before spilling to disk.
# WARNING	2024-12-17 11:39:07	AbstractOpticalDuplicateFinderCommandLineProgram	A field field parsed out of a read name was expected to contain an integer and did not. Read name: vcrs_1252641_28fW. Cause: String 'vcrs_1252641_28fW' did not start with a parsable number.
# INFO	2024-12-17 11:39:12	MarkDuplicates	Read     1,000,000 records.  Elapsed time: 00:00:04s.  Time for last 1,000,000:    4s.  Last read position: 10:13,701,369
# INFO	2024-12-17 11:39:12	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:15	MarkDuplicates	Read     2,000,000 records.  Elapsed time: 00:00:07s.  Time for last 1,000,000:    2s.  Last read position: 12:14,840,928
# INFO	2024-12-17 11:39:15	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:18	MarkDuplicates	Read     3,000,000 records.  Elapsed time: 00:00:10s.  Time for last 1,000,000:    3s.  Last read position: 15:45,442,829
# INFO	2024-12-17 11:39:18	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:22	MarkDuplicates	Read     4,000,000 records.  Elapsed time: 00:00:14s.  Time for last 1,000,000:    3s.  Last read position: 17:54,936,010
# INFO	2024-12-17 11:39:22	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:25	MarkDuplicates	Read     5,000,000 records.  Elapsed time: 00:00:17s.  Time for last 1,000,000:    3s.  Last read position: 19:58,573,004
# INFO	2024-12-17 11:39:25	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:29	MarkDuplicates	Read     6,000,000 records.  Elapsed time: 00:00:21s.  Time for last 1,000,000:    3s.  Last read position: 21:45,795,747
# INFO	2024-12-17 11:39:29	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:32	MarkDuplicates	Read     7,000,000 records.  Elapsed time: 00:00:24s.  Time for last 1,000,000:    2s.  Last read position: 4:94,006,417
# INFO	2024-12-17 11:39:32	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:35	MarkDuplicates	Read     8,000,000 records.  Elapsed time: 00:00:27s.  Time for last 1,000,000:    2s.  Last read position: 6:90,472,064
# INFO	2024-12-17 11:39:35	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:37	MarkDuplicates	Read     9,000,000 records.  Elapsed time: 00:00:29s.  Time for last 1,000,000:    2s.  Last read position: 9:5,462,930
# INFO	2024-12-17 11:39:37	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2024-12-17 11:39:39	MarkDuplicates	Read 9718092 records. 0 pairs never matched.
# INFO	2024-12-17 11:39:40	MarkDuplicates	After buildSortedReadEndLists freeMemory: 5085389848; totalMemory: 6761218048; maxMemory: 32178700288
# INFO	2024-12-17 11:39:40	MarkDuplicates	Will retain up to 1005584384 duplicate indices before spilling to disk.
# INFO	2024-12-17 11:39:44	MarkDuplicates	Traversing read pair information and detecting duplicates.
# INFO	2024-12-17 11:39:44	MarkDuplicates	Traversing fragment information and detecting duplicates.
# INFO	2024-12-17 11:39:46	MarkDuplicates	Sorting list of duplicate records.
# INFO	2024-12-17 11:39:46	MarkDuplicates	After generateDuplicateIndexes freeMemory: 9613280504; totalMemory: 17699962880; maxMemory: 32178700288
# INFO	2024-12-17 11:39:46	MarkDuplicates	Marking 1752703 records as duplicates.
# INFO	2024-12-17 11:39:46	MarkDuplicates	Found 0 optical duplicate clusters.
# INFO	2024-12-17 11:39:46	MarkDuplicates	Reads are assumed to be ordered by: coordinate
# INFO	2024-12-17 11:40:33	MarkDuplicates	Written    10,000,000 records.  Elapsed time: 00:00:46s.  Time for last 10,000,000:   46s.  Last read position: */*
# INFO	2024-12-17 11:40:41	MarkDuplicates	Writing complete. Closing input iterator.
# INFO	2024-12-17 11:40:41	MarkDuplicates	Duplicate Index cleanup.
# INFO	2024-12-17 11:40:41	MarkDuplicates	Getting Memory Stats.
# INFO	2024-12-17 11:40:41	MarkDuplicates	Before output close freeMemory: 1878087072; totalMemory: 1912602624; maxMemory: 32178700288
# INFO	2024-12-17 11:40:41	MarkDuplicates	Closed outputs. Getting more Memory Stats.
# INFO	2024-12-17 11:40:41	MarkDuplicates	After output close freeMemory: 637337024; totalMemory: 671088640; maxMemory: 32178700288
# [Tue Dec 17 11:40:41 PST 2024] picard.sam.markduplicates.MarkDuplicates done. Elapsed time: 1.58 minutes.
# Runtime.totalMemory()=671088640

# %% [markdown]
# 4. SplitNCigarReads

# %%
_ = pysam.faidx(reference_genome_fasta)

# !$gatk SplitNCigarReads \
    -R $reference_genome_fasta \
    -I $marked_duplicates_bam \
    -O $split_n_cigar_reads_bam
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar SplitNCigarReads -R /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa -I /home/jrich/data/varseek_data/gatk_dec17/alignment/marked_duplicates.bam -O /home/jrich/data/varseek_data/gatk_dec17/alignment/split_n_cigar_reads.bam
# 11:40:57.443 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 11:40:57.547 INFO  SplitNCigarReads - ------------------------------------------------------------
# 11:40:57.549 INFO  SplitNCigarReads - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 11:40:57.549 INFO  SplitNCigarReads - For support and documentation go to https://software.broadinstitute.org/gatk/
# 11:40:57.550 INFO  SplitNCigarReads - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 11:40:57.550 INFO  SplitNCigarReads - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 11:40:57.550 INFO  SplitNCigarReads - Start Date/Time: December 17, 2024 at 11:40:57 AM PST
# 11:40:57.550 INFO  SplitNCigarReads - ------------------------------------------------------------
# 11:40:57.550 INFO  SplitNCigarReads - ------------------------------------------------------------
# 11:40:57.550 INFO  SplitNCigarReads - HTSJDK Version: 4.1.1
# 11:40:57.551 INFO  SplitNCigarReads - Picard Version: 3.2.0
# 11:40:57.551 INFO  SplitNCigarReads - Built for Spark Version: 3.5.0
# 11:40:57.551 INFO  SplitNCigarReads - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 11:40:57.551 INFO  SplitNCigarReads - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 11:40:57.551 INFO  SplitNCigarReads - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 11:40:57.551 INFO  SplitNCigarReads - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 11:40:57.551 INFO  SplitNCigarReads - Deflater: IntelDeflater
# 11:40:57.551 INFO  SplitNCigarReads - Inflater: IntelInflater
# 11:40:57.551 INFO  SplitNCigarReads - GCS max retries/reopens: 20
# 11:40:57.552 INFO  SplitNCigarReads - Requester pays: disabled
# 11:40:57.552 INFO  SplitNCigarReads - Initializing engine
# 11:40:57.759 INFO  SplitNCigarReads - Done initializing engine
# 11:40:57.822 INFO  ProgressMeter - Starting traversal
# 11:40:57.822 INFO  ProgressMeter -        Current Locus  Elapsed Minutes       Reads Processed     Reads/Minute
# 11:41:07.851 INFO  ProgressMeter -           1:55547013              0.2                300000        1798561.2
# 11:41:17.861 INFO  ProgressMeter -          1:158592966              0.3                615000        1841593.1
# 11:41:27.877 INFO  ProgressMeter -          1:241767673              0.5                922000        1840809.3
# 11:41:37.892 INFO  ProgressMeter -          10:98287204              0.7               1208000        1808970.0
# 11:41:47.893 INFO  ProgressMeter -          11:33565183              0.8               1496000        1792726.0
# 11:41:57.893 INFO  ProgressMeter -         11:102562461              1.0               1782000        1779953.1
# 11:42:07.923 INFO  ProgressMeter -          12:49086760              1.2               2080000        1780364.6
# 11:42:17.930 INFO  ProgressMeter -         12:119772961              1.3               2357000        1765432.9
# 11:42:27.930 INFO  ProgressMeter -          14:30108028              1.5               2678000        1783252.9
# 11:42:37.976 INFO  ProgressMeter -          15:42867932              1.7               2978000        1784088.2
# 11:42:48.013 INFO  ProgressMeter -           16:4787896              1.8               3265000        1777854.4
# 11:42:58.039 INFO  ProgressMeter -          16:70698775              2.0               3500000        1746870.2
# 11:43:08.061 INFO  ProgressMeter -          17:26687579              2.2               3798000        1749773.5
# 11:43:18.091 INFO  ProgressMeter -          17:62542053              2.3               4049000        1731994.9
# 11:43:28.120 INFO  ProgressMeter -           19:3179065              2.5               4357000        1739367.6
# 11:43:38.147 INFO  ProgressMeter -          19:35823456              2.7               4660000        1743979.3
# 11:43:48.182 INFO  ProgressMeter -          19:54649706              2.8               4929000        1735991.3
# 11:43:58.182 INFO  ProgressMeter -           2:75882295              3.0               5215000        1734882.8
# 11:44:08.197 INFO  ProgressMeter -          2:187487077              3.2               5503000        1734384.6
# 11:44:18.223 INFO  ProgressMeter -          20:34087947              3.3               5793000        1734448.4
# 11:44:28.239 INFO  ProgressMeter -          22:29881742              3.5               6088000        1736006.2
# 11:44:38.259 INFO  ProgressMeter -           3:48643202              3.7               6379000        1736294.1
# 11:44:48.277 INFO  ProgressMeter -          3:142243010              3.8               6639000        1728508.6
# 11:44:58.287 INFO  ProgressMeter -           4:55599293              4.0               6910000        1724173.8
# 11:45:08.295 INFO  ProgressMeter -          4:187629264              4.2               7175000        1718761.9
# 11:45:18.298 INFO  ProgressMeter -          5:137781048              4.3               7468000        1720248.5
# 11:45:28.331 INFO  ProgressMeter -           6:32548622              4.5               7825000        1735629.8
# 11:45:38.361 INFO  ProgressMeter -          6:138619855              4.7               8092000        1730693.1
# 11:45:48.386 INFO  ProgressMeter -           7:87183102              4.8               8379000        1730233.1
# 11:45:58.404 INFO  ProgressMeter -           8:17843552              5.0               8683000        1733249.1
# 11:46:08.471 INFO  ProgressMeter -             9:117682              5.2               8987000        1735796.6
# 11:46:18.509 INFO  ProgressMeter -          9:135458603              5.3               9275000        1735347.8
# 11:46:28.534 INFO  ProgressMeter -           X:99890571              5.5               9557000        1733916.3
# 11:46:38.531 INFO  ProgressMeter -             unmapped              5.7              10787000        1899632.5
# 11:46:45.038 INFO  SplitNCigarReads - 0 read(s) filtered by: AllowAllReadsReadFilter
#
# 11:46:45.224 INFO  OverhangFixingManager - Overhang Fixing Manager saved 4575 reads in the first pass
# 11:46:45.230 INFO  SplitNCigarReads - Starting traversal pass 2
# 11:46:48.554 INFO  ProgressMeter -           1:16909208              5.8              12693000        2171413.9
# 11:46:58.581 INFO  ProgressMeter -           1:59248546              6.0              12899000        2145322.2
# 11:47:08.934 INFO  ProgressMeter -          1:150484074              6.2              13087000        2115862.9
# 11:47:18.978 INFO  ProgressMeter -          1:176863962              6.4              13291000        2092225.2
# 11:47:28.980 INFO  ProgressMeter -          1:236645717              6.5              13494000        2069864.7
# 11:47:39.015 INFO  ProgressMeter -          10:70231558              6.7              13701000        2049054.1
# 11:47:49.017 INFO  ProgressMeter -         10:115534644              6.9              13866000        2023288.4
# 11:47:59.341 INFO  ProgressMeter -          11:22646250              7.0              14067000        2002339.2
# 11:48:09.655 INFO  ProgressMeter -          11:68213952              7.2              14292000        1985776.8
# 11:48:19.659 INFO  ProgressMeter -         11:126174078              7.4              14485000        1967023.9
# 11:48:29.931 INFO  ProgressMeter -          12:48418611              7.5              14669000        1946751.5
# 11:48:39.995 INFO  ProgressMeter -          12:99020245              7.7              14870000        1930454.3
# 11:48:49.996 INFO  ProgressMeter -          13:21562486              7.9              15025000        1909261.9
# 11:49:00.002 INFO  ProgressMeter -          14:24658853              8.0              15257000        1898510.5
# 11:49:10.010 INFO  ProgressMeter -         14:105413863              8.2              15482000        1887335.3
# 11:49:20.059 INFO  ProgressMeter -          15:72057433              8.4              15675000        1872629.3
# 11:49:30.098 INFO  ProgressMeter -           16:9017208              8.5              15867000        1858423.1
# 11:49:41.118 INFO  ProgressMeter -          16:67964441              8.7              16065000        1841989.1
# 11:55:39.196 INFO  SplitNCigarReads - Shutting down engine
# [December 17, 2024 at 11:55:39 AM PST] org.broadinstitute.hellbender.tools.walkers.rnaseq.SplitNCigarReads done. Elapsed time: 14.70 minutes.
# Runtime.totalMemory()=1711276032

# %% [markdown]
# 5. BaseRecalibrator

# %%
##  -I in old version, -F in new version
# if not os.path.exists(f"{ensembl_germline_vcf_filtered}.idx"):
#     !$gatk IndexFeatureFile -I $ensembl_germline_vcf_filtered  # TODO: ~81092000/324780532 processed before error - current error being a duplicate G in REF/ALT column

if not os.path.exists(f"{genomes1000_vcf}.idx"):
    # !$gatk IndexFeatureFile -I $genomes1000_vcf

# TODO: uncomment once I install bgzip
# if not os.path.exists(f"{panel_of_normals_vcf_filtered}.idx"):
#     !gatk IndexFeatureFile -I $panel_of_normals_vcf_filtered

# %%
# TODO: when I fix !$gatk IndexFeatureFile -I $ensembl_germline_vcf_filtered, add back --known-sites $ensembl_germline_vcf_filtered
# !$gatk BaseRecalibrator \
    -I $split_n_cigar_reads_bam \
    -R $reference_genome_fasta \
    --use-original-qualities \
    --known-sites $genomes1000_vcf \
    -O $recal_data_table

# -known-sites ${dbSNP_vcf} \
# -known-sites ${sep=" --known-sites " known_indels_sites_VCFs}
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar BaseRecalibrator -I /home/jrich/data/varseek_data/gatk_dec17/alignment/split_n_cigar_reads.bam -R /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa --use-original-qualities --known-sites /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/1000GENOMES-phase_3.vcf -O /home/jrich/data/varseek_data/gatk_dec17/alignment/recal_data.table
# 11:55:41.727 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 11:55:41.867 INFO  BaseRecalibrator - ------------------------------------------------------------
# 11:55:41.872 INFO  BaseRecalibrator - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 11:55:41.872 INFO  BaseRecalibrator - For support and documentation go to https://software.broadinstitute.org/gatk/
# 11:55:41.872 INFO  BaseRecalibrator - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 11:55:41.872 INFO  BaseRecalibrator - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 11:55:41.873 INFO  BaseRecalibrator - Start Date/Time: December 17, 2024 at 11:55:41 AM PST
# 11:55:41.873 INFO  BaseRecalibrator - ------------------------------------------------------------
# 11:55:41.873 INFO  BaseRecalibrator - ------------------------------------------------------------
# 11:55:41.915 INFO  BaseRecalibrator - HTSJDK Version: 4.1.1
# 11:55:41.916 INFO  BaseRecalibrator - Picard Version: 3.2.0
# 11:55:41.916 INFO  BaseRecalibrator - Built for Spark Version: 3.5.0
# 11:55:41.916 INFO  BaseRecalibrator - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 11:55:41.917 INFO  BaseRecalibrator - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 11:55:41.917 INFO  BaseRecalibrator - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 11:55:41.918 INFO  BaseRecalibrator - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 11:55:41.918 INFO  BaseRecalibrator - Deflater: IntelDeflater
# 11:55:41.918 INFO  BaseRecalibrator - Inflater: IntelInflater
# 11:55:41.919 INFO  BaseRecalibrator - GCS max retries/reopens: 20
# 11:55:41.919 INFO  BaseRecalibrator - Requester pays: disabled
# 11:55:41.920 INFO  BaseRecalibrator - Initializing engine
# 11:55:42.230 INFO  FeatureManager - Using codec VCFCodec to read file file:///home/jrich/data/varseek_data/reference/ensembl_grch37_release93/1000GENOMES-phase_3.vcf
# 11:55:42.472 WARN  IndexUtils - Feature file "file:///home/jrich/data/varseek_data/reference/ensembl_grch37_release93/1000GENOMES-phase_3.vcf" appears to contain no sequence dictionary. Attempting to retrieve a sequence dictionary from the associated index file
# 11:55:42.563 INFO  BaseRecalibrator - Done initializing engine
# 11:55:42.569 INFO  BaseRecalibrationEngine - The covariates being used here:
# 11:55:42.569 INFO  BaseRecalibrationEngine - 	ReadGroupCovariate
# 11:55:42.569 INFO  BaseRecalibrationEngine - 	QualityScoreCovariate
# 11:55:42.569 INFO  BaseRecalibrationEngine - 	ContextCovariate
# 11:55:42.569 INFO  BaseRecalibrationEngine - 	CycleCovariate
# 11:55:42.575 INFO  ProgressMeter - Starting traversal
# 11:55:42.576 INFO  ProgressMeter -        Current Locus  Elapsed Minutes       Reads Processed     Reads/Minute
# 11:55:52.591 INFO  ProgressMeter -           1:91182488              0.2                576000        3451857.8
# 11:56:02.598 INFO  ProgressMeter -          1:204131141              0.3               1171000        3509315.2
# 11:56:12.609 INFO  ProgressMeter -          10:95115385              0.5               1728000        3452317.5
# 11:56:22.610 INFO  ProgressMeter -          11:63174141              0.7               2342000        3510104.2
# 11:56:32.627 INFO  ProgressMeter -          12:30873767              0.8               2949000        3535335.4
# 11:56:42.649 INFO  ProgressMeter -          13:24233189              1.0               3566000        3561666.6
# 11:56:52.650 INFO  ProgressMeter -          14:99959851              1.2               4168000        3568849.6
# 11:57:02.656 INFO  ProgressMeter -          16:19127150              1.3               4848000        3632367.6
# 11:57:12.667 INFO  ProgressMeter -          17:26686338              1.5               5510000        3669663.7
# 11:57:22.667 INFO  ProgressMeter -          18:45566993              1.7               6197000        3714819.5
# 11:57:32.669 INFO  ProgressMeter -          19:42794385              1.8               6906000        3763761.2
# 11:57:42.678 INFO  ProgressMeter -           2:97035163              2.0               7598000        3795773.6
# 11:57:52.687 INFO  ProgressMeter -          2:233127917              2.2               8203000        3782799.2
# 11:58:02.699 INFO  ProgressMeter -          22:25308662              2.3               8833000        3782275.4
# 11:58:12.716 INFO  ProgressMeter -           3:78734896              2.5               9436000        3770905.6
# 11:58:22.725 INFO  ProgressMeter -           4:56841082              2.7              10058000        3768264.4
# 11:58:32.732 INFO  ProgressMeter -           5:60839282              2.8              10614000        3742683.2
# 11:58:42.739 INFO  ProgressMeter -           6:31600521              3.0              11243000        3744276.0
# 11:58:52.740 INFO  ProgressMeter -           7:12397040              3.2              11878000        3747732.2
# 11:59:02.741 INFO  ProgressMeter -          7:150698909              3.3              12461000        3735218.4
# 11:59:12.748 INFO  ProgressMeter -          8:144642048              3.5              12971000        3702967.1
# 11:59:22.758 INFO  ProgressMeter -           X:37653030              3.7              13629000        3713927.6
# 11:59:30.736 INFO  BaseRecalibrator - 2893894 read(s) filtered by: MappingQualityNotZeroReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 3059289 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 5953183 total reads filtered out of 20005939 reads processed
# 11:59:30.736 INFO  ProgressMeter -     GL000209.1:25564              3.8              14052756        3695500.4
# 11:59:30.736 INFO  ProgressMeter - Traversal complete. Processed 14052756 total reads in 3.8 minutes.
# 11:59:30.759 INFO  BaseRecalibrator - Calculating quantized quality scores...
# 11:59:30.768 INFO  BaseRecalibrator - Writing recalibration report...
# 11:59:30.868 INFO  BaseRecalibrator - ...done!
# 11:59:30.869 INFO  BaseRecalibrator - BaseRecalibrator was able to recalibrate 14052756 reads
# 11:59:30.869 INFO  BaseRecalibrator - Shutting down engine
# [December 17, 2024 at 11:59:30 AM PST] org.broadinstitute.hellbender.tools.walkers.bqsr.BaseRecalibrator done. Elapsed time: 3.82 minutes.
# Runtime.totalMemory()=1224736768
# Tool returned:
# SUCCESS

# %% [markdown]
# 6. Apply Recalibration

# %%
if apply_bqsr:
    # !$gatk ApplyBQSR \
        --add-output-sam-program-record \
        -R $reference_genome_fasta \
        -I $split_n_cigar_reads_bam \
        --use-original-qualities \
        --bqsr-recal-file $recal_data_table \
        -O $recalibrated_bam
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar ApplyBQSR --add-output-sam-program-record -R /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa -I /home/jrich/data/varseek_data/gatk_dec17/alignment/split_n_cigar_reads.bam --use-original-qualities --bqsr-recal-file /home/jrich/data/varseek_data/gatk_dec17/alignment/recal_data.table -O /home/jrich/data/varseek_data/gatk_dec17/alignment/recalibrated.bam
# 11:59:33.127 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 11:59:33.267 INFO  ApplyBQSR - ------------------------------------------------------------
# 11:59:33.272 INFO  ApplyBQSR - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 11:59:33.272 INFO  ApplyBQSR - For support and documentation go to https://software.broadinstitute.org/gatk/
# 11:59:33.272 INFO  ApplyBQSR - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 11:59:33.272 INFO  ApplyBQSR - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 11:59:33.273 INFO  ApplyBQSR - Start Date/Time: December 17, 2024 at 11:59:33 AM PST
# 11:59:33.273 INFO  ApplyBQSR - ------------------------------------------------------------
# 11:59:33.273 INFO  ApplyBQSR - ------------------------------------------------------------
# 11:59:33.274 INFO  ApplyBQSR - HTSJDK Version: 4.1.1
# 11:59:33.274 INFO  ApplyBQSR - Picard Version: 3.2.0
# 11:59:33.274 INFO  ApplyBQSR - Built for Spark Version: 3.5.0
# 11:59:33.275 INFO  ApplyBQSR - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 11:59:33.275 INFO  ApplyBQSR - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 11:59:33.275 INFO  ApplyBQSR - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 11:59:33.275 INFO  ApplyBQSR - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 11:59:33.276 INFO  ApplyBQSR - Deflater: IntelDeflater
# 11:59:33.276 INFO  ApplyBQSR - Inflater: IntelInflater
# 11:59:33.276 INFO  ApplyBQSR - GCS max retries/reopens: 20
# 11:59:33.276 INFO  ApplyBQSR - Requester pays: disabled
# 11:59:33.277 INFO  ApplyBQSR - Initializing engine
# 11:59:33.484 INFO  ApplyBQSR - Done initializing engine
# 11:59:33.509 INFO  ProgressMeter - Starting traversal
# 11:59:33.510 INFO  ProgressMeter -        Current Locus  Elapsed Minutes       Reads Processed     Reads/Minute
# 11:59:43.521 INFO  ProgressMeter -           1:75037657              0.2                617000        3699040.8
# 11:59:53.522 INFO  ProgressMeter -          1:172557900              0.3               1210000        3628004.6
# 12:00:03.531 INFO  ProgressMeter -          10:46321858              0.5               1863000        3723393.6
# 12:00:13.541 INFO  ProgressMeter -           11:9985405              0.7               2517000        3772670.5
# 12:00:23.552 INFO  ProgressMeter -         11:117063972              0.8               3197000        3833180.1
# 12:00:33.558 INFO  ProgressMeter -          12:69652394              1.0               3903000        3899945.0
# 12:00:43.566 INFO  ProgressMeter -         13:109707826              1.2               4567000        3911442.3
# 12:00:53.572 INFO  ProgressMeter -          15:41801299              1.3               5210000        3904522.8
# 12:01:03.573 INFO  ProgressMeter -          16:19800160              1.5               5845000        3893984.1
# 12:01:13.575 INFO  ProgressMeter -           17:7577105              1.7               6481000        3886074.1
# 12:01:23.581 INFO  ProgressMeter -          17:59482680              1.8               7150000        3897484.4
# 12:01:33.591 INFO  ProgressMeter -           19:8660646              2.0               7865000        3929847.4
# 12:01:43.593 INFO  ProgressMeter -          19:46828851              2.2               8514000        3927061.4
# 12:01:53.599 INFO  ProgressMeter -           2:71058125              2.3               9157000        3921991.3
# 12:02:03.609 INFO  ProgressMeter -          2:203922049              2.5               9797000        3916241.4
# 12:02:13.612 INFO  ProgressMeter -          20:62366511              2.7              10457000        3918901.2
# 12:02:23.611 INFO  ProgressMeter -           3:38648218              2.8              11178000        3942834.0
# 12:02:33.629 INFO  ProgressMeter -          3:151463297              3.0              11803000        3931755.8
# 12:02:43.634 INFO  ProgressMeter -           4:85781565              3.2              12389000        3909784.7
# 12:02:53.638 INFO  ProgressMeter -           5:88056805              3.3              13049000        3912215.7
# 12:03:03.651 INFO  ProgressMeter -           6:30307685              3.5              13709000        3914247.6
# 12:03:13.651 INFO  ProgressMeter -          6:143095546              3.7              14288000        3894249.1
# 12:03:23.658 INFO  ProgressMeter -          7:100853870              3.8              14935000        3893598.4
# 12:03:33.669 INFO  ProgressMeter -           8:87392955              4.0              15577000        3891688.0
# 12:03:43.676 INFO  ProgressMeter -          9:113341598              4.2              16217000        3889512.9
# 12:03:53.692 INFO  ProgressMeter -           X:91134184              4.3              16856000        3887140.1
# 12:04:03.694 INFO  ProgressMeter -             unmapped              4.5              17528000        3892472.9
# 12:04:13.695 INFO  ProgressMeter -             unmapped              4.7              18171000        3891228.6
# 12:04:23.704 INFO  ProgressMeter -             unmapped              4.8              18882000        3904022.5
# 12:04:33.704 INFO  ProgressMeter -             unmapped              5.0              19582000        3913869.0
# 12:04:40.076 INFO  ApplyBQSR - 0 read(s) filtered by: WellformedReadFilter
#
# 12:04:40.078 INFO  ProgressMeter -             unmapped              5.1              20005939        3915478.0
# 12:04:40.078 INFO  ProgressMeter - Traversal complete. Processed 20005939 total reads in 5.1 minutes.
# 12:04:40.118 INFO  ApplyBQSR - Shutting down engine
# [December 17, 2024 at 12:04:40 PM PST] org.broadinstitute.hellbender.tools.walkers.bqsr.ApplyBQSR done. Elapsed time: 5.12 minutes.
# Runtime.totalMemory()=1224736768

# %% [markdown]
# 7. AnalyzeCovariates

# %%
# !$gatk AnalyzeCovariates \
    -bqsr $recal_data_table \
    -plots $covariates_plot
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar AnalyzeCovariates -bqsr /home/jrich/data/varseek_data/gatk_dec17/alignment/recal_data.table -plots /home/jrich/data/varseek_data/gatk_dec17/alignment/AnalyzeCovariates.pdf
# 12:04:42.118 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 12:04:42.274 INFO  AnalyzeCovariates - ------------------------------------------------------------
# 12:04:42.279 INFO  AnalyzeCovariates - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 12:04:42.279 INFO  AnalyzeCovariates - For support and documentation go to https://software.broadinstitute.org/gatk/
# 12:04:42.279 INFO  AnalyzeCovariates - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 12:04:42.279 INFO  AnalyzeCovariates - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 12:04:42.280 INFO  AnalyzeCovariates - Start Date/Time: December 17, 2024 at 12:04:42 PM PST
# 12:04:42.280 INFO  AnalyzeCovariates - ------------------------------------------------------------
# 12:04:42.280 INFO  AnalyzeCovariates - ------------------------------------------------------------
# 12:04:42.281 INFO  AnalyzeCovariates - HTSJDK Version: 4.1.1
# 12:04:42.281 INFO  AnalyzeCovariates - Picard Version: 3.2.0
# 12:04:42.281 INFO  AnalyzeCovariates - Built for Spark Version: 3.5.0
# 12:04:42.282 INFO  AnalyzeCovariates - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 12:04:42.282 INFO  AnalyzeCovariates - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 12:04:42.282 INFO  AnalyzeCovariates - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 12:04:42.282 INFO  AnalyzeCovariates - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 12:04:42.283 INFO  AnalyzeCovariates - Deflater: IntelDeflater
# 12:04:42.283 INFO  AnalyzeCovariates - Inflater: IntelInflater
# 12:04:42.283 INFO  AnalyzeCovariates - GCS max retries/reopens: 20
# 12:04:42.283 INFO  AnalyzeCovariates - Requester pays: disabled
# 12:04:42.284 INFO  AnalyzeCovariates - Initializing engine
# 12:04:42.284 INFO  AnalyzeCovariates - Done initializing engine
# 12:04:42.360 INFO  AnalyzeCovariates - Generating csv file '/tmp/AnalyzeCovariates12010810566073720718.csv'
# 12:04:42.397 INFO  AnalyzeCovariates - Generating plots file '/home/jrich/data/varseek_data/gatk_dec17/alignment/AnalyzeCovariates.pdf'
# 12:04:42.876 INFO  AnalyzeCovariates - Shutting down engine
# [December 17, 2024 at 12:04:42 PM PST] org.broadinstitute.hellbender.tools.walkers.bqsr.AnalyzeCovariates done. Elapsed time: 0.01 minutes.
# Runtime.totalMemory()=285212672
# org.broadinstitute.hellbender.utils.R.RScriptExecutorException:
# Rscript exited with 1
# Command Line: Rscript -e tempLibDir = '/tmp/Rlib.7970728703873025841';source('/tmp/BQSR.9402434179959131733.R'); /tmp/AnalyzeCovariates12010810566073720718.csv /home/jrich/data/varseek_data/gatk_dec17/alignment/recal_data.table /home/jrich/data/varseek_data/gatk_dec17/alignment/AnalyzeCovariates.pdf
# Stdout:
# Stderr: Error in library("ggplot2") : there is no package called ‘ggplot2’
# Calls: source -> withVisible -> eval -> eval -> library
# Execution halted
#
# 	at org.broadinstitute.hellbender.utils.R.RScriptExecutor.getScriptException(RScriptExecutor.java:79)
# 	at org.broadinstitute.hellbender.utils.R.RScriptExecutor.getScriptException(RScriptExecutor.java:18)
# 	at org.broadinstitute.hellbender.utils.runtime.ScriptExecutor.executeCuratedArgs(ScriptExecutor.java:112)
# 	at org.broadinstitute.hellbender.utils.R.RScriptExecutor.exec(RScriptExecutor.java:125)
# 	at org.broadinstitute.hellbender.utils.recalibration.RecalUtils.generatePlots(RecalUtils.java:360)
# 	at org.broadinstitute.hellbender.tools.walkers.bqsr.AnalyzeCovariates.generatePlots(AnalyzeCovariates.java:329)
# 	at org.broadinstitute.hellbender.tools.walkers.bqsr.AnalyzeCovariates.doWork(AnalyzeCovariates.java:341)
# 	at org.broadinstitute.hellbender.cmdline.CommandLineProgram.runTool(CommandLineProgram.java:149)
# 	at org.broadinstitute.hellbender.cmdline.CommandLineProgram.instanceMainPostParseArgs(CommandLineProgram.java:198)
# 	at org.broadinstitute.hellbender.cmdline.CommandLineProgram.instanceMain(CommandLineProgram.java:217)
# 	at org.broadinstitute.hellbender.Main.runCommandLineProgram(Main.java:166)
# 	at org.broadinstitute.hellbender.Main.mainEntry(Main.java:209)
# 	at org.broadinstitute.hellbender.Main.main(Main.java:306)

# %% [markdown]
# 8a. HaplotypeCaller

# %%
# !$gatk --java-options "-Xmx4g" HaplotypeCaller  \
    -R $reference_genome_fasta \
    -I $recalibrated_bam \
    -O $haplotypecaller_unfiltered_vcf \
    # --standard-min-confidence-threshold-for-calling 20 \
    --dont-use-soft-clipped-bases \
    --disable-tool-default-read-filters
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -Xmx4g -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar HaplotypeCaller -R /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa -I /home/jrich/data/varseek_data/gatk_dec17/alignment/recalibrated.bam -O /home/jrich/data/varseek_data/gatk_dec17/vcfs/haplotypecaller/haplotypecaller_output_unfiltered.g.vcf.gz --standard-min-confidence-threshold-for-calling 20 -dont-use-soft-clipped-bases
# 12:04:45.464 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 12:04:45.638 INFO  HaplotypeCaller - ------------------------------------------------------------
# 12:04:45.643 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 12:04:45.644 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 12:04:45.644 INFO  HaplotypeCaller - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 12:04:45.644 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 12:04:45.645 INFO  HaplotypeCaller - Start Date/Time: December 17, 2024 at 12:04:45 PM PST
# 12:04:45.645 INFO  HaplotypeCaller - ------------------------------------------------------------
# 12:04:45.645 INFO  HaplotypeCaller - ------------------------------------------------------------
# 12:04:45.646 INFO  HaplotypeCaller - HTSJDK Version: 4.1.1
# 12:04:45.646 INFO  HaplotypeCaller - Picard Version: 3.2.0
# 12:04:45.647 INFO  HaplotypeCaller - Built for Spark Version: 3.5.0
# 12:04:45.647 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 12:04:45.647 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 12:04:45.648 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 12:04:45.648 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 12:04:45.648 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 12:04:45.649 INFO  HaplotypeCaller - Inflater: IntelInflater
# 12:04:45.649 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 12:04:45.649 INFO  HaplotypeCaller - Requester pays: disabled
# 12:04:45.650 INFO  HaplotypeCaller - Initializing engine
# 12:04:45.937 INFO  HaplotypeCaller - Done initializing engine
# 12:04:45.953 INFO  NativeLibraryLoader - Loading libgkl_utils.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.so
# 12:04:45.969 INFO  NativeLibraryLoader - Loading libgkl_smithwaterman.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_smithwaterman.so
# 12:04:45.970 INFO  IntelSmithWaterman - Using CPU-supported AVX-512 instructions
# 12:04:45.970 INFO  SmithWatermanAligner - Using AVX accelerated SmithWaterman implementation
# 12:04:45.974 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 12:04:45.985 INFO  NativeLibraryLoader - Loading libgkl_pairhmm_omp.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm_omp.so
# 12:04:46.046 INFO  IntelPairHmm - Using CPU-supported AVX-512 instructions
# 12:04:46.046 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 12:04:46.047 INFO  IntelPairHmm - Available threads: 88
# 12:04:46.047 INFO  IntelPairHmm - Requested threads: 4
# 12:04:46.048 INFO  PairHMM - Using the OpenMP multi-threaded AVX-accelerated native PairHMM implementation
# 12:04:46.102 INFO  ProgressMeter - Starting traversal
# 12:04:46.103 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 12:04:46.783 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position 1:69617 and possibly subsequent; at least 10 samples must have called genotypes
# 12:04:56.108 INFO  ProgressMeter -            1:3776359              0.2                 13660          81927.2
# 12:05:06.110 INFO  ProgressMeter -           1:12073704              0.3                 42780         128295.1
# 12:05:16.113 INFO  ProgressMeter -           1:19477338              0.5                 68830         137614.1
# 12:05:26.127 INFO  ProgressMeter -           1:26688256              0.7                 94500         141668.5
# 12:05:36.144 INFO  ProgressMeter -           1:27686809              0.8                 98130         117661.9
# 12:05:46.156 INFO  ProgressMeter -           1:36887700              1.0                130500         130384.8
# 12:05:56.160 INFO  ProgressMeter -           1:44804667              1.2                158560         135798.0
# 12:06:06.160 INFO  ProgressMeter -           1:54339612              1.3                191780         143732.6
# 12:06:16.215 INFO  ProgressMeter -           1:70504125              1.5                247090         164521.9
# 12:06:26.215 INFO  ProgressMeter -           1:89427116              1.7                311390         186625.0
# 12:06:36.215 INFO  ProgressMeter -          1:107894895              1.8                374320         203966.9
# 12:06:46.293 INFO  ProgressMeter -          1:117122685              2.0                406680         203018.6
# 12:06:56.387 INFO  ProgressMeter -          1:147231267              2.2                508060         233978.1
# 12:07:06.850 INFO  ProgressMeter -          1:152280945              2.3                526030         224244.9
# 12:07:16.852 INFO  ProgressMeter -          1:155230172              2.5                537060         213756.6
# 12:07:26.853 INFO  ProgressMeter -          1:158817656              2.7                550360         205422.1
# 12:44:27.340 INFO  ProgressMeter -          8:128752592             39.7               9362230         235900.0
# 12:44:37.356 INFO  ProgressMeter -          8:144398947             39.9               9415390         236245.8
# 12:44:47.356 INFO  ProgressMeter -            9:3076134             40.0               9433460         235713.4
# 12:44:57.358 INFO  ProgressMeter -           9:20986343             40.2               9494310         236249.9
# 12:45:07.377 INFO  ProgressMeter -           9:35383005             40.4               9543250         236485.0
# 12:45:17.377 INFO  ProgressMeter -           9:60214982             40.5               9626840         237575.2
# 12:45:27.377 INFO  ProgressMeter -           9:86186951             40.7               9714460         238755.5
# 12:45:37.379 INFO  ProgressMeter -           9:99005640             40.9               9758290         238854.1
# 12:45:47.397 INFO  ProgressMeter -          9:112018366             41.0               9802920         238969.9
# 12:45:57.403 INFO  ProgressMeter -          9:124462388             41.2               9845750         239042.3
# 12:46:07.418 INFO  ProgressMeter -          9:131708442             41.4               9871430         238698.4
# 12:46:17.426 INFO  ProgressMeter -          9:138595765             41.5               9895870         238328.2
# 12:46:27.426 INFO  ProgressMeter -             X:348608             41.7               9907110         237644.9
# 12:46:37.433 INFO  ProgressMeter -           X:18274918             41.9               9968030         238153.5
# 12:46:47.452 INFO  ProgressMeter -           X:36104906             42.0              10028490         238645.8
# 12:46:57.462 INFO  ProgressMeter -           X:45053111             42.2              10058910         238423.2
# 12:47:07.464 INFO  ProgressMeter -           X:53611656             42.4              10088780         238190.1
# 12:47:17.463 INFO  ProgressMeter -           X:69837944             42.5              10143880         238552.3
# 12:47:27.463 INFO  ProgressMeter -           X:80490195             42.7              10180340         238475.0
# 12:47:37.465 INFO  ProgressMeter -          X:102341062             42.9              10253940         239264.8
# 12:47:47.506 INFO  ProgressMeter -          X:118221243             43.0              10308110         239593.3
# 12:47:57.514 INFO  ProgressMeter -          X:132458484             43.2              10356570         239790.0
# 12:48:07.518 INFO  ProgressMeter -          X:149102874             43.4              10412860         240166.1
# 12:48:17.518 INFO  ProgressMeter -            Y:2784635             43.5              10444040         239962.8
# 12:48:27.518 INFO  ProgressMeter -           Y:56359806             43.7              10622850         243140.1
# 12:48:29.124 INFO  HaplotypeCaller - 202280 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 3024823 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 3227103 total reads filtered out of 17131377 reads processed
# 12:48:29.124 INFO  ProgressMeter -      GL000207.1:1801             43.7              10653298         243687.7
# 12:48:29.124 INFO  ProgressMeter - Traversal complete. Processed 10653298 total regions in 43.7 minutes.
# 12:48:29.161 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 3.1503133610000003
# 12:48:29.161 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 336.417706181
# 12:48:29.161 INFO  SmithWatermanAligner - Total compute time in native Smith-Waterman : 109.03 sec
# 12:48:29.162 INFO  HaplotypeCaller - Shutting down engine
# [December 17, 2024 at 12:48:29 PM PST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 43.73 minutes.
# Runtime.totalMemory()=1482686464

# %% [markdown]
# 8.5a. MergeVcfs

# %%
# merged_vcf = haplotypecaller_merged.vcf
# 
# !$java -jar $picard_jar MergeVcfs \
#     --INPUT $vcf1 \
#     --INPUT $vcf2 \
#     --OUTPUT $merged_vcf

# %% [markdown]
# 9a. VariantFiltration

# %%
# cosmic_vcf = ""

# !$gatk VariantFiltration \
    -R $reference_genome_fasta \
    -V $haplotypecaller_unfiltered_vcf \
    -O $haplotypecaller_filtered_vcf \
    --window 35 \
    --cluster 3 \
    --filter-name "FS" \
    --filter "FS > 30.0" \
    --filter-name "QD" \
    --filter "QD < 2.0"

    # --mask $cosmic_vcf \
    # --mask-name "COSMIC" \
    # --filter-not-in-mask \
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar VariantFiltration -R /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa -V /home/jrich/data/varseek_data/gatk_dec17/vcfs/haplotypecaller/haplotypecaller_output_unfiltered.g.vcf.gz -O /home/jrich/data/varseek_data/gatk_dec17/vcfs/haplotypecaller/haplotypecaller_output_filtered.vcf.gz --window 35 --cluster 3 --filter-name FS --filter FS > 30.0 --filter-name QD --filter QD < 2.0
# 12:48:31.600 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 12:48:31.748 INFO  VariantFiltration - ------------------------------------------------------------
# 12:48:31.752 INFO  VariantFiltration - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 12:48:31.753 INFO  VariantFiltration - For support and documentation go to https://software.broadinstitute.org/gatk/
# 12:48:31.753 INFO  VariantFiltration - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 12:48:31.753 INFO  VariantFiltration - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 12:48:31.753 INFO  VariantFiltration - Start Date/Time: December 17, 2024 at 12:48:31 PM PST
# 12:48:31.754 INFO  VariantFiltration - ------------------------------------------------------------
# 12:48:31.754 INFO  VariantFiltration - ------------------------------------------------------------
# 12:48:31.755 INFO  VariantFiltration - HTSJDK Version: 4.1.1
# 12:48:31.755 INFO  VariantFiltration - Picard Version: 3.2.0
# 12:48:31.755 INFO  VariantFiltration - Built for Spark Version: 3.5.0
# 12:48:31.755 INFO  VariantFiltration - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 12:48:31.755 INFO  VariantFiltration - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 12:48:31.756 INFO  VariantFiltration - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 12:48:31.756 INFO  VariantFiltration - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 12:48:31.756 INFO  VariantFiltration - Deflater: IntelDeflater
# 12:48:31.756 INFO  VariantFiltration - Inflater: IntelInflater
# 12:48:31.757 INFO  VariantFiltration - GCS max retries/reopens: 20
# 12:48:31.757 INFO  VariantFiltration - Requester pays: disabled
# 12:48:31.757 INFO  VariantFiltration - Initializing engine
# 12:48:31.962 INFO  FeatureManager - Using codec VCFCodec to read file file:///home/jrich/data/varseek_data/gatk_dec17/vcfs/haplotypecaller/haplotypecaller_output_unfiltered.g.vcf.gz
# 12:48:32.128 INFO  VariantFiltration - Done initializing engine
# 12:48:32.265 INFO  ProgressMeter - Starting traversal
# 12:48:32.266 INFO  ProgressMeter -        Current Locus  Elapsed Minutes    Variants Processed  Variants/Minute
# 12:48:40.014 INFO  ProgressMeter -          X:154159470              0.1                168144        1302432.2
# 12:48:40.015 INFO  ProgressMeter - Traversal complete. Processed 168144 total variants in 0.1 minutes.
# 12:48:40.049 INFO  VariantFiltration - Shutting down engine
# [December 17, 2024 at 12:48:40 PM PST] org.broadinstitute.hellbender.tools.walkers.filters.VariantFiltration done. Elapsed time: 0.14 minutes.
# Runtime.totalMemory()=2986344448

# %% [markdown]
# 10a. Do the filtering

# %%
# !$gatk SelectVariants \
     -V $haplotypecaller_filtered_vcf \
     --exclude-filtered true \
     -O $haplotypecaller_filtered_applied_vcf
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar SelectVariants -V /home/jrich/data/varseek_data/gatk_dec17/vcfs/haplotypecaller/haplotypecaller_output_filtered.vcf.gz --exclude-filtered true -O /home/jrich/data/varseek_data/gatk_dec17/vcfs/haplotypecaller/haplotypecaller_output_filtered_applied.vcf.gz
# 12:48:42.492 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 12:48:42.604 INFO  SelectVariants - ------------------------------------------------------------
# 12:48:42.607 INFO  SelectVariants - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 12:48:42.607 INFO  SelectVariants - For support and documentation go to https://software.broadinstitute.org/gatk/
# 12:48:42.607 INFO  SelectVariants - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 12:48:42.608 INFO  SelectVariants - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 12:48:42.608 INFO  SelectVariants - Start Date/Time: December 17, 2024 at 12:48:42 PM PST
# 12:48:42.608 INFO  SelectVariants - ------------------------------------------------------------
# 12:48:42.608 INFO  SelectVariants - ------------------------------------------------------------
# 12:48:42.608 INFO  SelectVariants - HTSJDK Version: 4.1.1
# 12:48:42.609 INFO  SelectVariants - Picard Version: 3.2.0
# 12:48:42.609 INFO  SelectVariants - Built for Spark Version: 3.5.0
# 12:48:42.609 INFO  SelectVariants - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 12:48:42.609 INFO  SelectVariants - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 12:48:42.609 INFO  SelectVariants - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 12:48:42.609 INFO  SelectVariants - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 12:48:42.609 INFO  SelectVariants - Deflater: IntelDeflater
# 12:48:42.609 INFO  SelectVariants - Inflater: IntelInflater
# 12:48:42.610 INFO  SelectVariants - GCS max retries/reopens: 20
# 12:48:42.610 INFO  SelectVariants - Requester pays: disabled
# 12:48:42.610 INFO  SelectVariants - Initializing engine
# 12:48:42.702 INFO  FeatureManager - Using codec VCFCodec to read file file:///home/jrich/data/varseek_data/gatk_dec17/vcfs/haplotypecaller/haplotypecaller_output_filtered.vcf.gz
# 12:48:42.801 INFO  SelectVariants - Done initializing engine
# 12:48:42.838 INFO  ProgressMeter - Starting traversal
# 12:48:42.839 INFO  ProgressMeter -        Current Locus  Elapsed Minutes    Variants Processed  Variants/Minute
# 12:48:44.859 INFO  ProgressMeter -          X:154159470              0.0                168144        5006769.2
# 12:48:44.860 INFO  ProgressMeter - Traversal complete. Processed 168144 total variants in 0.0 minutes.
# 12:48:44.894 INFO  SelectVariants - Shutting down engine
# [December 17, 2024 at 12:48:44 PM PST] org.broadinstitute.hellbender.tools.walkers.variantutils.SelectVariants done. Elapsed time: 0.04 minutes.
# Runtime.totalMemory()=1224736768

# %% [markdown]
# 8b. Mutect2

# %%
# consider adding --disable-read-filter
# TODO: add --panel-of-normals $panel_of_normals_vcf_filtered once I install bgzip
# !$gatk Mutect2 \
    -R $reference_genome_fasta \
    -I $recalibrated_bam \
    -O $mutect2_unfiltered_vcf \
    --disable-tool-default-read-filters
    # --min-base-quality-score 20
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar Mutect2 -R /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa -I /home/jrich/data/varseek_data/gatk_dec17/alignment/recalibrated.bam -O /home/jrich/data/varseek_data/gatk_dec17/vcfs/mutect2/mutect2_output_unfiltered.g.vcf.gz --min-base-quality-score 20
# 12:48:47.156 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 12:48:47.301 INFO  Mutect2 - ------------------------------------------------------------
# 12:48:47.305 INFO  Mutect2 - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 12:48:47.305 INFO  Mutect2 - For support and documentation go to https://software.broadinstitute.org/gatk/
# 12:48:47.305 INFO  Mutect2 - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 12:48:47.305 INFO  Mutect2 - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 12:48:47.306 INFO  Mutect2 - Start Date/Time: December 17, 2024 at 12:48:47 PM PST
# 12:48:47.306 INFO  Mutect2 - ------------------------------------------------------------
# 12:48:47.306 INFO  Mutect2 - ------------------------------------------------------------
# 12:48:47.307 INFO  Mutect2 - HTSJDK Version: 4.1.1
# 12:48:47.307 INFO  Mutect2 - Picard Version: 3.2.0
# 12:48:47.307 INFO  Mutect2 - Built for Spark Version: 3.5.0
# 12:48:47.308 INFO  Mutect2 - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 12:48:47.308 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 12:48:47.308 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 12:48:47.308 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 12:48:47.309 INFO  Mutect2 - Deflater: IntelDeflater
# 12:48:47.309 INFO  Mutect2 - Inflater: IntelInflater
# 12:48:47.309 INFO  Mutect2 - GCS max retries/reopens: 20
# 12:48:47.309 INFO  Mutect2 - Requester pays: disabled
# 12:48:47.310 INFO  Mutect2 - Initializing engine
# 12:48:47.532 INFO  Mutect2 - Done initializing engine
# 12:48:47.543 INFO  NativeLibraryLoader - Loading libgkl_utils.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.so
# 12:48:47.545 INFO  NativeLibraryLoader - Loading libgkl_smithwaterman.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_smithwaterman.so
# 12:48:47.546 INFO  IntelSmithWaterman - Using CPU-supported AVX-512 instructions
# 12:48:47.546 INFO  SmithWatermanAligner - Using AVX accelerated SmithWaterman implementation
# 12:48:47.631 INFO  NativeLibraryLoader - Loading libgkl_pairhmm_omp.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm_omp.so
# 12:48:47.671 INFO  IntelPairHmm - Using CPU-supported AVX-512 instructions
# 12:48:47.671 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 12:48:47.671 INFO  IntelPairHmm - Available threads: 88
# 12:48:47.671 INFO  IntelPairHmm - Requested threads: 4
# 12:48:47.672 INFO  PairHMM - Using the OpenMP multi-threaded AVX-accelerated native PairHMM implementation
# 13:13:48.469 INFO  ProgressMeter -           7:30102696             25.0               8501430         339885.7
# 13:13:58.475 INFO  ProgressMeter -           7:48547983             25.2               8564820         340152.1
# 13:14:08.478 INFO  ProgressMeter -           7:77214505             25.3               8661900         341744.9
# 13:14:18.491 INFO  ProgressMeter -           7:97821224             25.5               8732310         342269.3
# 13:14:28.493 INFO  ProgressMeter -          7:103339778             25.7               8752780         340844.5
# 13:14:38.494 INFO  ProgressMeter -          7:124531836             25.8               8825020         341441.6
# 13:14:48.514 INFO  ProgressMeter -          7:141756234             26.0               8884490         341535.6
# 13:14:58.514 INFO  ProgressMeter -          7:157357051             26.2               8938350         341418.6
# 13:15:08.514 INFO  ProgressMeter -           8:22059354             26.3               9019570         342341.5
# 13:15:18.514 INFO  ProgressMeter -           8:40552888             26.5               9083220         342590.2
# 13:15:28.514 INFO  ProgressMeter -           8:66887883             26.7               9172460         343794.9
# 13:15:38.519 INFO  ProgressMeter -           8:92348213             26.8               9258900         344879.5
# 13:15:48.518 INFO  ProgressMeter -          8:113421899             27.0               9330870         345415.9
# 13:15:58.518 INFO  ProgressMeter -          8:137856632             27.2               9413840         346350.5
# 13:16:08.519 INFO  ProgressMeter -            9:4125979             27.3               9458020         345854.9
# 13:16:18.519 INFO  ProgressMeter -           9:32553670             27.5               9554340         347260.7
# 13:16:28.519 INFO  ProgressMeter -           9:58852669             27.7               9643510         348391.2
# 13:16:38.532 INFO  ProgressMeter -           9:90500640             27.8               9750470         350144.4
# 13:16:48.557 INFO  ProgressMeter -          9:109690412             28.0               9816350         350407.7
# 13:16:58.566 INFO  ProgressMeter -          9:127111642             28.2               9876500         350468.1
# 13:17:08.572 INFO  ProgressMeter -          9:135920557             28.3               9908140         349522.2
# 13:17:18.580 INFO  ProgressMeter -            X:1743329             28.5               9933810         348377.9
# 13:17:28.580 INFO  ProgressMeter -           X:25424055             28.7              10014570         349169.3
# 13:17:38.584 INFO  ProgressMeter -           X:48650426             28.8              10093540         349888.8
# 13:17:48.583 INFO  ProgressMeter -           X:68320287             29.0              10160900         350200.6
# 13:17:58.585 INFO  ProgressMeter -           X:92964728             29.2              10244600         351068.3
# 13:18:08.588 INFO  ProgressMeter -          X:115590746             29.3              10321690         351700.7
# 13:18:18.595 INFO  ProgressMeter -          X:135474551             29.5              10389570         352013.2
# 13:18:28.603 INFO  ProgressMeter -          X:153641189             29.7              10451710         352128.6
# 13:18:38.603 INFO  ProgressMeter -           Y:46149593             29.8              10611630         355520.1
# 13:18:42.098 INFO  Mutect2 - 202280 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappingQualityNotZeroReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 3024823 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonChimericOriginalAlignmentReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: ReadLengthReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 3227103 total reads filtered out of 17131377 reads processed
# 13:18:42.098 INFO  ProgressMeter -      GL000207.1:3601             29.9              10676112         356983.8
# 13:18:42.098 INFO  ProgressMeter - Traversal complete. Processed 10676112 total regions in 29.9 minutes.
# 13:18:42.247 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.659913592
# 13:18:42.247 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 22.915410091000002
# 13:18:42.247 INFO  SmithWatermanAligner - Total compute time in native Smith-Waterman : 9.40 sec
# 13:18:42.249 INFO  Mutect2 - Shutting down engine
# [December 17, 2024 at 1:18:42 PM PST] org.broadinstitute.hellbender.tools.walkers.mutect.Mutect2 done. Elapsed time: 29.92 minutes.
# Runtime.totalMemory()=1979711488
# Tool returned:
# SUCCESS

# %% [markdown]
# 9b. FilterMutectCalls

# %%
# # if multiple stats files:
# !$gatk MergeMutectStats -stats unfiltered1.vcf.stats -stats unfiltered2.vcf.stats -O unfiltered.vcf.stats

# stats_file = f"{mutect2_unfiltered_vcf}.stats"
# --stats $stats_file
# !$gatk FilterMutectCalls \
    -R $reference_genome_fasta \
    -V $mutect2_unfiltered_vcf \
    -O $mutect2_filtered_vcf
# Out:
# Using GATK jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar FilterMutectCalls -R /home/jrich/data/varseek_data/reference/ensembl_grch37_release93/Homo_sapiens.GRCh37.dna.primary_assembly.fa -V /home/jrich/data/varseek_data/gatk_dec17/vcfs/mutect2/mutect2_output_unfiltered.g.vcf.gz -O /home/jrich/data/varseek_data/gatk_dec17/vcfs/mutect2/mutect2_output_filtered.vcf.gz
# 13:18:44.872 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/home/jrich/opt/gatk-4.6.0.0/gatk-package-4.6.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 13:18:45.075 INFO  FilterMutectCalls - ------------------------------------------------------------
# 13:18:45.080 INFO  FilterMutectCalls - The Genome Analysis Toolkit (GATK) v4.6.0.0
# 13:18:45.081 INFO  FilterMutectCalls - For support and documentation go to https://software.broadinstitute.org/gatk/
# 13:18:45.081 INFO  FilterMutectCalls - Executing as jrich@dator on Linux v3.10.0-1127.13.1.el7.x86_64 amd64
# 13:18:45.081 INFO  FilterMutectCalls - Java runtime: OpenJDK 64-Bit Server VM v17.0.12+7
# 13:18:45.083 INFO  FilterMutectCalls - Start Date/Time: December 17, 2024 at 1:18:44 PM PST
# 13:18:45.083 INFO  FilterMutectCalls - ------------------------------------------------------------
# 13:18:45.083 INFO  FilterMutectCalls - ------------------------------------------------------------
# 13:18:45.084 INFO  FilterMutectCalls - HTSJDK Version: 4.1.1
# 13:18:45.084 INFO  FilterMutectCalls - Picard Version: 3.2.0
# 13:18:45.084 INFO  FilterMutectCalls - Built for Spark Version: 3.5.0
# 13:18:45.085 INFO  FilterMutectCalls - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 13:18:45.085 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 13:18:45.085 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 13:18:45.085 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 13:18:45.086 INFO  FilterMutectCalls - Deflater: IntelDeflater
# 13:18:45.086 INFO  FilterMutectCalls - Inflater: IntelInflater
# 13:18:45.086 INFO  FilterMutectCalls - GCS max retries/reopens: 20
# 13:18:45.086 INFO  FilterMutectCalls - Requester pays: disabled
# 13:18:45.087 INFO  FilterMutectCalls - Initializing engine
# 13:18:45.256 INFO  FeatureManager - Using codec VCFCodec to read file file:///home/jrich/data/varseek_data/gatk_dec17/vcfs/mutect2/mutect2_output_unfiltered.g.vcf.gz
# 13:18:45.379 INFO  FilterMutectCalls - Done initializing engine
# 13:18:45.485 INFO  ProgressMeter - Starting traversal
# 13:18:45.486 INFO  ProgressMeter -        Current Locus  Elapsed Minutes    Variants Processed  Variants/Minute
# 13:18:45.488 INFO  FilterMutectCalls - Starting pass 0 through the variants
# 13:18:49.082 INFO  FilterMutectCalls - Finished pass 0 through the variants
# 13:19:07.992 INFO  FilterMutectCalls - Starting pass 1 through the variants
# 13:19:08.013 INFO  ProgressMeter -            1:3329146              0.4                 36000          95902.0
# 13:19:10.727 INFO  FilterMutectCalls - Finished pass 1 through the variants
# 13:19:12.753 INFO  FilterMutectCalls - Starting pass 2 through the variants
# 13:19:15.163 INFO  FilterMutectCalls - Finished pass 2 through the variants
# 13:19:15.174 INFO  FilterMutectCalls - Starting pass 3 through the variants
# 13:19:18.032 INFO  ProgressMeter -          5:176070116              0.5                136000         250729.8
# 13:19:18.711 INFO  FilterMutectCalls - Finished pass 3 through the variants
# 13:19:18.718 INFO  FilterMutectCalls - No variants filtered by: AllowAllVariantsVariantFilter
# 13:19:18.718 INFO  FilterMutectCalls - 0 read(s) filtered by: AllowAllReadsReadFilter
#
# 13:19:18.718 INFO  ProgressMeter -          X:104464274              0.6                143512         259117.1
# 13:19:18.718 INFO  ProgressMeter - Traversal complete. Processed 143512 total variants in 0.6 minutes.
# 13:19:18.744 INFO  FilterMutectCalls - Shutting down engine
# [December 17, 2024 at 1:19:18 PM PST] org.broadinstitute.hellbender.tools.walkers.mutect.filtering.FilterMutectCalls done. Elapsed time: 0.57 minutes.
# Runtime.totalMemory()=1224736768

# %%
# !$gatk SelectVariants \
     -V $mutect2_filtered_vcf \
     --exclude-filtered true \
     -O $mutect2_filtered_applied_vcf

# %%
# def create_sample_vcf(output_path):
#     with open(output_path, "w") as vcf_file:
#         # Write VCF headers
#         vcf_file.write("##fileformat=VCFv4.2\n")
#         vcf_file.write("##source=SampleVCFGenerator\n")
#         vcf_file.write("##reference=GRCh37\n")
#         vcf_file.write("##INFO=<ID=DP,Number=1,Type=Integer,Description=\"Total Depth\">\n")
#         vcf_file.write("##INFO=<ID=AF,Number=A,Type=Float,Description=\"Allele Frequency\">\n")
#         vcf_file.write("##FILTER=<ID=PASS,Description=\"All filters passed\">\n")
#         vcf_file.write("##FORMAT=<ID=GT,Number=1,Type=String,Description=\"Genotype\">\n")
#         vcf_file.write("#CHROM\tPOS\tID\tREF\tALT\tQUAL\tFILTER\tINFO\tFORMAT\tsample1\n")
        
#         # Write sample variant entries
#         variants = [
#             ("1", 123456, ".", "G", "A", 50, "PASS", "DP=100;AF=0.5", "GT", "0/1"),
#             ("1", 234567, ".", "C", "T", 60, "PASS", "DP=200;AF=0.3", "GT", "1/1"),
#             ("2", 345678, ".", "T", "G", 70, "PASS", "DP=150;AF=0.1", "GT", "0/1"),
#             ("X", 456789, ".", "A", "C", 80, "PASS", "DP=120;AF=0.05", "GT", "0/0")
#         ]
        
#         for chrom, pos, var_id, ref, alt, qual, fltr, info, fmt, sample in variants:
#             vcf_file.write(f"{chrom}\t{pos}\t{var_id}\t{ref}\t{alt}\t{qual}\t{fltr}\t{info}\t{fmt}\t{sample}\n")

# # Usage
# create_sample_vcf("/home/jrich/data/varseek_data/gatk/sample.vcf")

# df_sample = vcf_to_dataframe("/home/jrich/data/varseek_data/gatk/sample.vcf")

# %% [markdown]
# # JUMP TO HERE

# %%
from varseek.utils import vcf_to_dataframe

# Convert VCF to DataFrame
df_hap = vcf_to_dataframe(haplotypecaller_vcf_final, additional_columns = True)
df_mut = vcf_to_dataframe(mutect2_vcf_final, additional_columns = True)

df_hap = df_hap[['CHROM', 'POS', 'ID', 'REF', 'ALT', 'INFO_DP']].rename(columns={'INFO_DP': 'DP_gatk_haplotypecaller'})
df_mut = df_mut[['CHROM', 'POS', 'ID', 'REF', 'ALT', 'INFO_DP']].rename(columns={'INFO_DP': 'DP_gatk_mutect2'})

# %%
cosmic_df = add_vcf_info_to_cosmic_tsv(cosmic_tsv=cosmic_tsv, reference_genome_fasta=reference_genome_fasta, cosmic_df_out = None, cosmic_cdna_info_csv = cosmic_cdna_info_csv, mutation_source = "cdna")
# Out:
# 100%|██████████| 15776/15776 [00:00<00:00, 65550.67it/s]
# 100%|██████████| 120017/120017 [00:01<00:00, 82982.94it/s]
# 1it [00:00, 596.37it/s]
# 1it [00:00, 3017.48it/s]
# 100%|██████████| 120017/120017 [00:00<00:00, 810548.31it/s]

# %%
# load in unique_mcrs_df
unique_mcrs_df = pd.read_csv(unique_mcrs_df_path)
unique_mcrs_df.rename(columns={'received_an_aligned_read': 'mutation_detected_vk', 'number_of_reads_aligned_to_this_item': 'DP_vk', 'mutation_expression_prediction_error': 'mutation_expression_prediction_error_vk', 'TP_crude': 'TP_vk', 'FP_crude': 'FP_vk', 'TN_crude': 'TN_vk', 'FN_crude': 'FN_vk', 'TP': 'TP_vk_read_specific', 'FP': 'FP_vk_read_specific', 'TN': 'TN_vk_read_specific', 'FN': 'FN_vk_read_specific'}, inplace=True)

from varseek.utils import safe_literal_eval
unique_mcrs_df["header_list"] = unique_mcrs_df["header_list"].apply(safe_literal_eval)
# Out:
# /tmp/ipykernel_314829/3565577588.py:2: DtypeWarning: Columns (36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   unique_mcrs_df = pd.read_csv(unique_mcrs_df_path)

# %%
mut_cosmic_merged_df = merge_gatk_and_cosmic(df_mut, cosmic_df, exact_position=False)  # change exact_position to True to merge based on exact position as before
id_set_mut = set(mut_cosmic_merged_df['ID'])

hap_cosmic_merged_df = merge_gatk_and_cosmic(df_hap, cosmic_df, exact_position=False)
id_set_hap = set(hap_cosmic_merged_df['ID'])

# %%
# Merge DP values into unique_mcrs_df
# Step 1: Remove rows with NaN values in 'ID' column
mutect2_cosmic_merged_df_for_merging = mut_cosmic_merged_df[['ID', 'DP_gatk_mutect2']].dropna(subset=['ID']).rename(columns={'ID': 'mcrs_header'})

# Step 2: Drop duplicates from 'ID' and 'DP_gatk_mutect2' columns
mutect2_cosmic_merged_df_for_merging = mutect2_cosmic_merged_df_for_merging.drop_duplicates()

# Step 3: Left merge with unique_mcrs_df
unique_mcrs_df = pd.merge(
    unique_mcrs_df,               # Left DataFrame
    mutect2_cosmic_merged_df_for_merging,         # Right DataFrame
    on='mcrs_header',
    how='left'
)


# Repeat for haplotypecaller
# Step 1: Remove rows with NaN values in 'ID' column
haplotypecaller_cosmic_merged_df_for_merging = hap_cosmic_merged_df[['ID', 'DP_gatk_haplotypecaller']].dropna(subset=['ID']).rename(columns={'ID': 'mcrs_header'})

# Step 2: Drop duplicates from 'ID' and 'DP_gatk_haplotypecaller' columns
haplotypecaller_cosmic_merged_df_for_merging = haplotypecaller_cosmic_merged_df_for_merging.drop_duplicates()

# Step 3: Left merge with unique_mcrs_df
unique_mcrs_df = pd.merge(
    unique_mcrs_df,               # Left DataFrame
    haplotypecaller_cosmic_merged_df_for_merging,         # Right DataFrame
    on='mcrs_header',
    how='left'
)

# %%
number_of_mutations_mutect = len(df_mut)
number_of_cosmic_mutations_mutect = len(mut_cosmic_merged_df.drop_duplicates(subset=['CHROM', 'POS', 'REF', 'ALT']))
number_of_mutations_haplotypecaller = len(df_hap)
number_of_cosmic_mutations_haplotypecaller = len(hap_cosmic_merged_df.drop_duplicates(subset=['CHROM', 'POS', 'REF', 'ALT']))

# %%
# unique_mcrs_df['header_list'] each contains a list of strings. I would like to make a new column unique_mcrs_df['mutation_detected_gatk_mutect2'] where each row is True if any value from the list unique_mcrs_df['mcrs_header'] is in the set id_set_mut  # keep in mind that my IDs are the mutation headers (ENST...), NOT mcrs headers or mcrs ids
unique_mcrs_df['mutation_detected_gatk_mutect2'] = unique_mcrs_df['header_list'].apply(
    lambda header_list: any(header in id_set_mut for header in header_list)
)

# calculate expression error
unique_mcrs_df['mutation_expression_prediction_error_gatk_mutect2'] = unique_mcrs_df['DP_gatk_mutect2'] - unique_mcrs_df['number_of_reads_mutant']  # positive means overpredicted, negative means underpredicted

unique_mcrs_df['TP'] = (unique_mcrs_df['included_in_synthetic_reads_mutant'] & unique_mcrs_df['mutation_detected_gatk_mutect2'])
unique_mcrs_df['FP'] = (~unique_mcrs_df['included_in_synthetic_reads_mutant'] & unique_mcrs_df['mutation_detected_gatk_mutect2'])
unique_mcrs_df['FN'] = (unique_mcrs_df['included_in_synthetic_reads_mutant'] & ~unique_mcrs_df['mutation_detected_gatk_mutect2'])
unique_mcrs_df['TN'] = (~unique_mcrs_df['included_in_synthetic_reads_mutant'] & ~unique_mcrs_df['mutation_detected_gatk_mutect2'])

mutect_stat_path = f"{gatk_parent}/reference_metrics_mutect2.txt"
metric_dictionary_reference = calculate_metrics(unique_mcrs_df, header_name = "mcrs_header", check_assertions = False, out = mutect_stat_path)
draw_confusion_matrix(metric_dictionary_reference)

true_set = set(unique_mcrs_df.loc[unique_mcrs_df['included_in_synthetic_reads_mutant'], 'mcrs_header'])
positive_set = set(unique_mcrs_df.loc[unique_mcrs_df['mutation_detected_gatk_mutect2'], 'mcrs_header'])
create_venn_diagram(true_set, positive_set, TN = metric_dictionary_reference['TN'], out_path = f"{gatk_parent}/venn_diagram_reference_cosmic_only_mutect2.png")


noncosmic_mutation_id_set = {f'mutect_fp_{i}' for i in range(1, number_of_mutations_mutect - number_of_cosmic_mutations_mutect + 1)}
positive_set_including_noncosmic_mutations = positive_set.union(noncosmic_mutation_id_set)

FP_including_noncosmic = metric_dictionary_reference['FP'] + len(positive_set_including_noncosmic_mutations)
accuracy, sensitivity, specificity = calculate_sensitivity_specificity(metric_dictionary_reference['TP'], metric_dictionary_reference['TP'], FP_including_noncosmic, metric_dictionary_reference['TP'])

with open(mutect_stat_path, "a") as file:
    file.write(f"FP including non-cosmic: {FP_including_noncosmic}\n")
    file.write(f"accuracy including non-cosmic: {accuracy}\n")
    file.write(f"specificity including non-cosmic: {specificity}\n")

create_venn_diagram(true_set, positive_set_including_noncosmic_mutations, TN = metric_dictionary_reference['TN'], out_path = f"{gatk_parent}/venn_diagram_reference_including_noncosmics_mutect2.png")

create_stratified_metric_bar_plot(unique_mcrs_df, 'number_of_reads_mutant', 'accuracy', overall_metric = metric_dictionary_reference['accuracy'], log_x_axis = False, out_path = f"{plot_output_folder}/accuracy_vs_number_of_reads_mutant.png")
#!!! create similar plots for y in {sensitivity, specificity}, and x in {number_of_reads_wt, tumor_purity} and determine cutoffs for which GATK is reliable

unique_mcrs_df.rename(columns={'TP': 'TP_gatk_mutect2', 'FP': 'FP_gatk_mutect2', 'TN': 'TN_gatk_mutect2', 'FN': 'FN_gatk_mutect2'}, inplace=True)
# Out:
# TP: 199998, FP: 1408, FN: 181247, TN: 4869016
# Accuracy: 0.9652196282743638, Sensitivity: 0.5245917979252187, Specificity: 0.9997109081262741
#                       Confusion Matrix
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓
# ┃                 ┃ Predicted Positive ┃ Predicted Negative ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩
# │ Actual Positive │       199998       │       181247       │
# │ Actual Negative │        1408        │      4869016       │
# └─────────────────┴────────────────────┴────────────────────┘
# /home/jrich/Desktop/varseek/varseek/utils/visualization_utils.py:362: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df.groupby(group_col).sum()

# %%
unique_mcrs_df['mutation_detected_gatk_haplotypecaller'] = unique_mcrs_df['header_list'].apply(
    lambda header_list: any(header in id_set_hap for header in header_list)
)

# calculate expression error
unique_mcrs_df['mutation_expression_prediction_error_gatk_haplotypecaller'] = unique_mcrs_df['DP_gatk_haplotypecaller'] - unique_mcrs_df['number_of_reads_mutant']  # positive means overpredicted, negative means underpredicted

unique_mcrs_df['TP'] = (unique_mcrs_df['included_in_synthetic_reads_mutant'] & unique_mcrs_df['mutation_detected_gatk_haplotypecaller'])
unique_mcrs_df['FP'] = (~unique_mcrs_df['included_in_synthetic_reads_mutant'] & unique_mcrs_df['mutation_detected_gatk_haplotypecaller'])
unique_mcrs_df['FN'] = (unique_mcrs_df['included_in_synthetic_reads_mutant'] & ~unique_mcrs_df['mutation_detected_gatk_haplotypecaller'])
unique_mcrs_df['TN'] = (~unique_mcrs_df['included_in_synthetic_reads_mutant'] & ~unique_mcrs_df['mutation_detected_gatk_haplotypecaller'])

haplotypecaller_stat_path = f"{gatk_parent}/reference_metrics_haplotypecaller.txt"
metric_dictionary_reference = calculate_metrics(unique_mcrs_df, header_name = "mcrs_header", check_assertions = False, out = haplotypecaller_stat_path)
draw_confusion_matrix(metric_dictionary_reference)

true_set = set(unique_mcrs_df.loc[unique_mcrs_df['included_in_synthetic_reads_mutant'], 'mcrs_header'])
positive_set = set(unique_mcrs_df.loc[unique_mcrs_df['mutation_detected_gatk_haplotypecaller'], 'mcrs_header'])
create_venn_diagram(true_set, positive_set, TN = metric_dictionary_reference['TN'], out_path = f"{gatk_parent}/venn_diagram_reference_cosmic_only_haplotypecaller.png")



noncosmic_mutation_id_set = {f'haplotypecaller_fp_{i}' for i in range(1, number_of_mutations_haplotypecaller - number_of_cosmic_mutations_haplotypecaller + 1)}
positive_set_including_noncosmic_mutations = positive_set.union(noncosmic_mutation_id_set)

FP_including_noncosmic = metric_dictionary_reference['FP'] + len(positive_set_including_noncosmic_mutations)
accuracy, sensitivity, specificity = calculate_sensitivity_specificity(metric_dictionary_reference['TP'], metric_dictionary_reference['TP'], FP_including_noncosmic, metric_dictionary_reference['TP'])

with open(haplotypecaller_stat_path, "a") as file:
    file.write(f"FP including non-cosmic: {FP_including_noncosmic}\n")
    file.write(f"accuracy including non-cosmic: {accuracy}\n")
    file.write(f"specificity including non-cosmic: {specificity}\n")

create_venn_diagram(true_set, positive_set_including_noncosmic_mutations, TN = metric_dictionary_reference['TN'], out_path = f"{gatk_parent}/venn_diagram_reference_including_noncosmics_haplotypecaller.png")

create_stratified_metric_bar_plot(unique_mcrs_df, 'number_of_reads_mutant', 'accuracy', overall_metric = metric_dictionary_reference['accuracy'], log_x_axis = False, out_path = f"{plot_output_folder}/accuracy_vs_number_of_reads_mutant.png")
#!!! create similar plots for y in {sensitivity, specificity}, and x in {number_of_reads_wt, tumor_purity} and determine cutoffs for which GATK is reliable

unique_mcrs_df.rename(columns={'TP': 'TP_gatk_haplotypecaller', 'FP': 'FP_gatk_haplotypecaller', 'TN': 'TN_gatk_haplotypecaller', 'FN': 'FN_gatk_haplotypecaller'}, inplace=True)
# Out:
# TP: 143736, FP: 3728, FN: 237509, TN: 4866696
# Accuracy: 0.9540646982892487, Sensitivity: 0.37701740350693125, Specificity: 0.9992345635616119
#                       Confusion Matrix
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓
# ┃                 ┃ Predicted Positive ┃ Predicted Negative ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩
# │ Actual Positive │       143736       │       237509       │
# │ Actual Negative │        3728        │      4866696       │
# └─────────────────┴────────────────────┴────────────────────┘
# /home/jrich/Desktop/varseek/varseek/utils/visualization_utils.py:362: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df.groupby(group_col).sum()

# %%
unique_mcrs_df_out = unique_mcrs_df_path.replace(".csv", "_with_gatk.csv")
unique_mcrs_df.to_csv(unique_mcrs_df_out, index=False)
